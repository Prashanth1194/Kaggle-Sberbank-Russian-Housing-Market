# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn import preprocessing
import xgboost as xgb
import datetime

# %%
#load files
train = pd.read_csv('train.csv', parse_dates=['timestamp'])
test = pd.read_csv('test.csv', parse_dates=['timestamp'])
id_test = test.id

# %%
#train = train[train['kremlin_km']>=0.1]

# %%
#clean data
bad_index = train[train.life_sq > train.full_sq].index
train.loc[bad_index, "life_sq"] = np.NaN
equal_index = [601,1896,2791]
test.loc[equal_index, "life_sq"] = test.loc[equal_index, "full_sq"]
bad_index = test[test.life_sq > test.full_sq].index
test.loc[bad_index, "life_sq"] = np.NaN
bad_index = train[train.life_sq < 5].index
train.loc[bad_index, "life_sq"] = np.NaN
bad_index = test[test.life_sq < 5].index
test.loc[bad_index, "life_sq"] = np.NaN
bad_index = train[train.full_sq < 5].index
train.loc[bad_index, "full_sq"] = np.NaN
bad_index = test[test.full_sq < 5].index
test.loc[bad_index, "full_sq"] = np.NaN
kitch_is_build_year = [13117]
train.loc[kitch_is_build_year, "build_year"] = train.loc[kitch_is_build_year, "kitch_sq"]
bad_index = train[train.kitch_sq >= train.life_sq].index
train.loc[bad_index, "kitch_sq"] = np.NaN
bad_index = test[test.kitch_sq >= test.life_sq].index
test.loc[bad_index, "kitch_sq"] = np.NaN
bad_index = train[(train.kitch_sq == 0).values + (train.kitch_sq == 1).values].index
train.loc[bad_index, "kitch_sq"] = np.NaN
bad_index = test[(test.kitch_sq == 0).values + (test.kitch_sq == 1).values].index
test.loc[bad_index, "kitch_sq"] = np.NaN
bad_index = train[(train.full_sq > 210) & (train.life_sq / train.full_sq < 0.3)].index
train.loc[bad_index, "full_sq"] = np.NaN
bad_index = test[(test.full_sq > 150) & (test.life_sq / test.full_sq < 0.3)].index
test.loc[bad_index, "full_sq"] = np.NaN
bad_index = train[train.life_sq > 300].index
train.loc[bad_index, ["life_sq", "full_sq"]] = np.NaN
bad_index = test[test.life_sq > 200].index
test.loc[bad_index, ["life_sq", "full_sq"]] = np.NaN
train.product_type.value_counts(normalize= True)
test.product_type.value_counts(normalize= True)
bad_index = train[train.build_year < 1500].index
train.loc[bad_index, "build_year"] = np.NaN
bad_index = test[test.build_year < 1500].index
test.loc[bad_index, "build_year"] = np.NaN
bad_index = train[train.num_room == 0].index
train.loc[bad_index, "num_room"] = np.NaN
bad_index = test[test.num_room == 0].index
test.loc[bad_index, "num_room"] = np.NaN
bad_index = [10076, 11621, 17764, 19390, 24007, 26713, 29172]
train.loc[bad_index, "num_room"] = np.NaN
bad_index = [3174, 7313]
test.loc[bad_index, "num_room"] = np.NaN
bad_index = train[(train.floor == 0).values * (train.max_floor == 0).values].index
train.loc[bad_index, ["max_floor", "floor"]] = np.NaN
bad_index = train[train.floor == 0].index
train.loc[bad_index, "floor"] = np.NaN
bad_index = train[train.max_floor == 0].index
train.loc[bad_index, "max_floor"] = np.NaN
bad_index = test[test.max_floor == 0].index
test.loc[bad_index, "max_floor"] = np.NaN
bad_index = train[train.floor > train.max_floor].index
train.loc[bad_index, "max_floor"] = np.NaN
bad_index = test[test.floor > test.max_floor].index
test.loc[bad_index, "max_floor"] = np.NaN
train.floor.describe(percentiles= [0.9999])
bad_index = [23584]
train.loc[bad_index, "floor"] = np.NaN
train.material.value_counts()
test.material.value_counts()
train.state.value_counts()
bad_index = train[train.state == 33].index
train.loc[bad_index, "state"] = np.NaN
test.state.value_counts()
# Out:
# C:\Users\prashanth.s\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# 2.0    2662
# 1.0    2266
# 3.0    1913
# 4.0     127
# Name: state, dtype: int64

# %%
# brings error down a lot by removing extreme price per sqm
train.loc[train.full_sq == 0, 'full_sq'] = 50
train = train[train.price_doc/train.full_sq <= 600000]
train = train[train.price_doc/train.full_sq >= 10000]

# %%
# Add month-year
month_year = (train.timestamp.dt.month + train.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
train['month_year_cnt'] = month_year.map(month_year_cnt_map)

month_year = (test.timestamp.dt.month + test.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
test['month_year_cnt'] = month_year.map(month_year_cnt_map)

# %%
# Add week-year count
week_year = (train.timestamp.dt.weekofyear + train.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
train['week_year_cnt'] = week_year.map(week_year_cnt_map)

week_year = (test.timestamp.dt.weekofyear + test.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
test['week_year_cnt'] = week_year.map(week_year_cnt_map)

# %%
# Add month and day-of-week
train['month'] = train.timestamp.dt.month
train['dow'] = train.timestamp.dt.dayofweek

test['month'] = test.timestamp.dt.month
test['dow'] = test.timestamp.dt.dayofweek

# %%
# Other feature engineering
train['rel_floor'] = train['floor'] / train['max_floor'].astype(float)
train['rel_kitch_sq'] = train['kitch_sq'] / train['full_sq'].astype(float)

test['rel_floor'] = test['floor'] / test['max_floor'].astype(float)
test['rel_kitch_sq'] = test['kitch_sq'] / test['full_sq'].astype(float)

train.apartment_name=train.sub_area + train['metro_km_avto'].astype(str)
test.apartment_name=test.sub_area + train['metro_km_avto'].astype(str)

train['room_size'] = train['life_sq'] / train['num_room'].astype(float)
test['room_size'] = test['life_sq'] / test['num_room'].astype(float)

# %%
rate_2016_q2 = 1
rate_2016_q1 = rate_2016_q2 / .99903
rate_2015_q4 = rate_2016_q1 / .9831
rate_2015_q3 = rate_2015_q4 / .9834
rate_2015_q2 = rate_2015_q3 / .9815
rate_2015_q1 = rate_2015_q2 / .9932
rate_2014_q4 = rate_2015_q1 / 1.0112
rate_2014_q3 = rate_2014_q4 / 1.0169
rate_2014_q2 = rate_2014_q3 / 1.0086
rate_2014_q1 = rate_2014_q2 / 1.0126
rate_2013_q4 = rate_2014_q1 / 0.9902
rate_2013_q3 = rate_2013_q4 / 1.0041
rate_2013_q2 = rate_2013_q3 / 1.0044
rate_2013_q1 = rate_2013_q2 / 1.0104
rate_2012_q4 = rate_2013_q1 / 0.9832
rate_2012_q3 = rate_2012_q4 / 1.0277
rate_2012_q2 = rate_2012_q3 / 1.0279
rate_2012_q1 = rate_2012_q2 / 1.0279
rate_2011_q4 = rate_2012_q1 / 1.076
rate_2011_q3 = rate_2011_q4 / 1.0236
rate_2011_q2 = rate_2011_q3 / 1
rate_2011_q1 = rate_2011_q2 / 1.011

# %%
# test data
test['average_q_price'] = 1

test_2016_q2_index = test.loc[test['timestamp'].dt.year == 2016].loc[test['timestamp'].dt.month >= 4].loc[test['timestamp'].dt.month <= 7].index
test.loc[test_2016_q2_index, 'average_q_price'] = rate_2016_q2
# test.loc[test_2016_q2_index, 'year_q'] = '2016_q2'

test_2016_q1_index = test.loc[test['timestamp'].dt.year == 2016].loc[test['timestamp'].dt.month >= 1].loc[test['timestamp'].dt.month < 4].index
test.loc[test_2016_q1_index, 'average_q_price'] = rate_2016_q1
# test.loc[test_2016_q2_index, 'year_q'] = '2016_q1'

test_2015_q4_index = test.loc[test['timestamp'].dt.year == 2015].loc[test['timestamp'].dt.month >= 10].loc[test['timestamp'].dt.month < 12].index
test.loc[test_2015_q4_index, 'average_q_price'] = rate_2015_q4
# test.loc[test_2015_q4_index, 'year_q'] = '2015_q4'

test_2015_q3_index = test.loc[test['timestamp'].dt.year == 2015].loc[test['timestamp'].dt.month >= 7].loc[test['timestamp'].dt.month < 10].index
test.loc[test_2015_q3_index, 'average_q_price'] = rate_2015_q3
# test.loc[test_2015_q3_index, 'year_q'] = '2015_q3'

# test_2015_q2_index = test.loc[test['timestamp'].dt.year == 2015].loc[test['timestamp'].dt.month >= 4].loc[test['timestamp'].dt.month < 7].index
# test.loc[test_2015_q2_index, 'average_q_price'] = rate_2015_q2

# test_2015_q1_index = test.loc[test['timestamp'].dt.year == 2015].loc[test['timestamp'].dt.month >= 4].loc[test['timestamp'].dt.month < 7].index
# test.loc[test_2015_q1_index, 'average_q_price'] = rate_2015_q1


# train 2015
train['average_q_price'] = 1

train_2015_q4_index = train.loc[train['timestamp'].dt.year == 2015].loc[train['timestamp'].dt.month >= 10].loc[train['timestamp'].dt.month <= 12].index
# train.loc[train_2015_q4_index, 'price_doc'] = train.loc[train_2015_q4_index, 'price_doc'] * rate_2015_q4
train.loc[train_2015_q4_index, 'average_q_price'] = rate_2015_q4

train_2015_q3_index = train.loc[train['timestamp'].dt.year == 2015].loc[train['timestamp'].dt.month >= 7].loc[train['timestamp'].dt.month < 10].index
#train.loc[train_2015_q3_index, 'price_doc'] = train.loc[train_2015_q3_index, 'price_doc'] * rate_2015_q3
train.loc[train_2015_q3_index, 'average_q_price'] = rate_2015_q3

train_2015_q2_index = train.loc[train['timestamp'].dt.year == 2015].loc[train['timestamp'].dt.month >= 4].loc[train['timestamp'].dt.month < 7].index
#train.loc[train_2015_q2_index, 'price_doc'] = train.loc[train_2015_q2_index, 'price_doc'] * rate_2015_q2
train.loc[train_2015_q2_index, 'average_q_price'] = rate_2015_q2

train_2015_q1_index = train.loc[train['timestamp'].dt.year == 2015].loc[train['timestamp'].dt.month >= 1].loc[train['timestamp'].dt.month < 4].index
#train.loc[train_2015_q1_index, 'price_doc'] = train.loc[train_2015_q1_index, 'price_doc'] * rate_2015_q1
train.loc[train_2015_q1_index, 'average_q_price'] = rate_2015_q1


# train 2014
train_2014_q4_index = train.loc[train['timestamp'].dt.year == 2014].loc[train['timestamp'].dt.month >= 10].loc[train['timestamp'].dt.month <= 12].index
#train.loc[train_2014_q4_index, 'price_doc'] = train.loc[train_2014_q4_index, 'price_doc'] * rate_2014_q4
train.loc[train_2014_q4_index, 'average_q_price'] = rate_2014_q4

train_2014_q3_index = train.loc[train['timestamp'].dt.year == 2014].loc[train['timestamp'].dt.month >= 7].loc[train['timestamp'].dt.month < 10].index
#train.loc[train_2014_q3_index, 'price_doc'] = train.loc[train_2014_q3_index, 'price_doc'] * rate_2014_q3
train.loc[train_2014_q3_index, 'average_q_price'] = rate_2014_q3

train_2014_q2_index = train.loc[train['timestamp'].dt.year == 2014].loc[train['timestamp'].dt.month >= 4].loc[train['timestamp'].dt.month < 7].index
#train.loc[train_2014_q2_index, 'price_doc'] = train.loc[train_2014_q2_index, 'price_doc'] * rate_2014_q2
train.loc[train_2014_q2_index, 'average_q_price'] = rate_2014_q2

train_2014_q1_index = train.loc[train['timestamp'].dt.year == 2014].loc[train['timestamp'].dt.month >= 1].loc[train['timestamp'].dt.month < 4].index
#train.loc[train_2014_q1_index, 'price_doc'] = train.loc[train_2014_q1_index, 'price_doc'] * rate_2014_q1
train.loc[train_2014_q1_index, 'average_q_price'] = rate_2014_q1


# train 2013
train_2013_q4_index = train.loc[train['timestamp'].dt.year == 2013].loc[train['timestamp'].dt.month >= 10].loc[train['timestamp'].dt.month <= 12].index
# train.loc[train_2013_q4_index, 'price_doc'] = train.loc[train_2013_q4_index, 'price_doc'] * rate_2013_q4
train.loc[train_2013_q4_index, 'average_q_price'] = rate_2013_q4

train_2013_q3_index = train.loc[train['timestamp'].dt.year == 2013].loc[train['timestamp'].dt.month >= 7].loc[train['timestamp'].dt.month < 10].index
# train.loc[train_2013_q3_index, 'price_doc'] = train.loc[train_2013_q3_index, 'price_doc'] * rate_2013_q3
train.loc[train_2013_q3_index, 'average_q_price'] = rate_2013_q3

train_2013_q2_index = train.loc[train['timestamp'].dt.year == 2013].loc[train['timestamp'].dt.month >= 4].loc[train['timestamp'].dt.month < 7].index
# train.loc[train_2013_q2_index, 'price_doc'] = train.loc[train_2013_q2_index, 'price_doc'] * rate_2013_q2
train.loc[train_2013_q2_index, 'average_q_price'] = rate_2013_q2

train_2013_q1_index = train.loc[train['timestamp'].dt.year == 2013].loc[train['timestamp'].dt.month >= 1].loc[train['timestamp'].dt.month < 4].index
# train.loc[train_2013_q1_index, 'price_doc'] = train.loc[train_2013_q1_index, 'price_doc'] * rate_2013_q1
train.loc[train_2013_q1_index, 'average_q_price'] = rate_2013_q1


# train 2012
train_2012_q4_index = train.loc[train['timestamp'].dt.year == 2012].loc[train['timestamp'].dt.month >= 10].loc[train['timestamp'].dt.month <= 12].index
# train.loc[train_2012_q4_index, 'price_doc'] = train.loc[train_2012_q4_index, 'price_doc'] * rate_2012_q4
train.loc[train_2012_q4_index, 'average_q_price'] = rate_2012_q4

train_2012_q3_index = train.loc[train['timestamp'].dt.year == 2012].loc[train['timestamp'].dt.month >= 7].loc[train['timestamp'].dt.month < 10].index
# train.loc[train_2012_q3_index, 'price_doc'] = train.loc[train_2012_q3_index, 'price_doc'] * rate_2012_q3
train.loc[train_2012_q3_index, 'average_q_price'] = rate_2012_q3

train_2012_q2_index = train.loc[train['timestamp'].dt.year == 2012].loc[train['timestamp'].dt.month >= 4].loc[train['timestamp'].dt.month < 7].index
# train.loc[train_2012_q2_index, 'price_doc'] = train.loc[train_2012_q2_index, 'price_doc'] * rate_2012_q2
train.loc[train_2012_q2_index, 'average_q_price'] = rate_2012_q2

train_2012_q1_index = train.loc[train['timestamp'].dt.year == 2012].loc[train['timestamp'].dt.month >= 1].loc[train['timestamp'].dt.month < 4].index
# train.loc[train_2012_q1_index, 'price_doc'] = train.loc[train_2012_q1_index, 'price_doc'] * rate_2012_q1
train.loc[train_2012_q1_index, 'average_q_price'] = rate_2012_q1


# train 2011
train_2011_q4_index = train.loc[train['timestamp'].dt.year == 2011].loc[train['timestamp'].dt.month >= 10].loc[train['timestamp'].dt.month <= 12].index
# train.loc[train_2011_q4_index, 'price_doc'] = train.loc[train_2011_q4_index, 'price_doc'] * rate_2011_q4
train.loc[train_2011_q4_index, 'average_q_price'] = rate_2011_q4

train_2011_q3_index = train.loc[train['timestamp'].dt.year == 2011].loc[train['timestamp'].dt.month >= 7].loc[train['timestamp'].dt.month < 10].index
# train.loc[train_2011_q3_index, 'price_doc'] = train.loc[train_2011_q3_index, 'price_doc'] * rate_2011_q3
train.loc[train_2011_q3_index, 'average_q_price'] = rate_2011_q3

train_2011_q2_index = train.loc[train['timestamp'].dt.year == 2011].loc[train['timestamp'].dt.month >= 4].loc[train['timestamp'].dt.month < 7].index
# train.loc[train_2011_q2_index, 'price_doc'] = train.loc[train_2011_q2_index, 'price_doc'] * rate_2011_q2
train.loc[train_2011_q2_index, 'average_q_price'] = rate_2011_q2

train_2011_q1_index = train.loc[train['timestamp'].dt.year == 2011].loc[train['timestamp'].dt.month >= 1].loc[train['timestamp'].dt.month < 4].index
# train.loc[train_2011_q1_index, 'price_doc'] = train.loc[train_2011_q1_index, 'price_doc'] * rate_2011_q1
train.loc[train_2011_q1_index, 'average_q_price'] = rate_2011_q1

train['price_doc'] = train['price_doc'] * train['average_q_price']
# train.drop('average_q_price', axis=1, inplace=True)

print('price changed done')

y_train = train["price_doc"]
# x_train = train.drop(["id", "timestamp", "price_doc"], axis=1)
# x_test = test.drop(["id", "timestamp"], axis=1)

x_train = train.drop(["id", "timestamp", "price_doc", "average_q_price"], axis=1)
x_test = test.drop(["id", "timestamp", "average_q_price"], axis=1)
# Out:
# price changed done

# %%
num_train = len(x_train)
x_all = pd.concat([x_train, x_test])

for c in x_all.columns:
    if x_all[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_all[c].values))
        x_all[c] = lbl.transform(list(x_all[c].values))
        #a = pd.get_dummies(x_all[c],prefix=c)
        #train.drop(c,axis=1,inplace=True)
        #train = train.join(a)
        #x_train.drop(c,axis=1,inplace=True)

x_train = x_all[:num_train]
x_test = x_all[num_train:]

# %%
xgb_params = {
    'eta': 0.05,
    'max_depth': 6,
    'subsample': 0.6,
    'colsample_bytree': 1,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test)

# %%
cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=500, early_stopping_rounds=10,
    verbose_eval=1, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
# Out:
# [0]	train-rmse:8.36817e+06	test-rmse:8.37654e+06
# [1]	train-rmse:8.00476e+06	test-rmse:8.01873e+06
# [2]	train-rmse:7.66139e+06	test-rmse:7.68312e+06
# [3]	train-rmse:7.33421e+06	test-rmse:7.366e+06
# [4]	train-rmse:7.02637e+06	test-rmse:7.06893e+06
# [5]	train-rmse:6.73291e+06	test-rmse:6.78063e+06
# [6]	train-rmse:6.45667e+06	test-rmse:6.51378e+06
# [7]	train-rmse:6.19503e+06	test-rmse:6.2597e+06
# [8]	train-rmse:5.94945e+06	test-rmse:6.02112e+06
# [9]	train-rmse:5.71595e+06	test-rmse:5.79544e+06
# [10]	train-rmse:5.49415e+06	test-rmse:5.58133e+06
# [11]	train-rmse:5.28655e+06	test-rmse:5.38353e+06
# [12]	train-rmse:5.08981e+06	test-rmse:5.19695e+06
# [13]	train-rmse:4.90499e+06	test-rmse:5.02112e+06
# [14]	train-rmse:4.72899e+06	test-rmse:4.85793e+06
# [15]	train-rmse:4.56679e+06	test-rmse:4.70553e+06
# [16]	train-rmse:4.41031e+06	test-rmse:4.55944e+06
# [17]	train-rmse:4.26406e+06	test-rmse:4.42301e+06
# [18]	train-rmse:4.12711e+06	test-rmse:4.29612e+06
# [19]	train-rmse:3.99797e+06	test-rmse:4.17845e+06
# [20]	train-rmse:3.87773e+06	test-rmse:4.06682e+06
# [21]	train-rmse:3.76553e+06	test-rmse:3.96624e+06
# [22]	train-rmse:3.65789e+06	test-rmse:3.86762e+06
# [23]	train-rmse:3.55792e+06	test-rmse:3.781e+06
# [24]	train-rmse:3.46679e+06	test-rmse:3.70004e+06
# [25]	train-rmse:3.37765e+06	test-rmse:3.62123e+06
# [26]	train-rmse:3.29592e+06	test-rmse:3.54896e+06
# [27]	train-rmse:3.21862e+06	test-rmse:3.48332e+06
# [28]	train-rmse:3.14604e+06	test-rmse:3.42304e+06
# [29]	train-rmse:3.07878e+06	test-rmse:3.3658e+06
# [30]	train-rmse:3.01514e+06	test-rmse:3.31172e+06
# [31]	train-rmse:2.95506e+06	test-rmse:3.2628e+06
# [32]	train-rmse:2.90004e+06	test-rmse:3.21728e+06
# [33]	train-rmse:2.84704e+06	test-rmse:3.1739e+06
# [34]	train-rmse:2.79786e+06	test-rmse:3.13598e+06
# [35]	train-rmse:2.75222e+06	test-rmse:3.10044e+06
# [36]	train-rmse:2.70934e+06	test-rmse:3.06602e+06
# [37]	train-rmse:2.66906e+06	test-rmse:3.03348e+06
# [38]	train-rmse:2.63206e+06	test-rmse:3.0044e+06
# [39]	train-rmse:2.59664e+06	test-rmse:2.97747e+06
# [40]	train-rmse:2.56434e+06	test-rmse:2.95417e+06
# [41]	train-rmse:2.53462e+06	test-rmse:2.93192e+06
# [42]	train-rmse:2.50493e+06	test-rmse:2.90828e+06
# [43]	train-rmse:2.47765e+06	test-rmse:2.88935e+06
# [44]	train-rmse:2.4521e+06	test-rmse:2.87081e+06
# [45]	train-rmse:2.42784e+06	test-rmse:2.85353e+06
# [46]	train-rmse:2.40587e+06	test-rmse:2.83984e+06
# [47]	train-rmse:2.38417e+06	test-rmse:2.82542e+06
# [48]	train-rmse:2.36292e+06	test-rmse:2.81173e+06
# [49]	train-rmse:2.34533e+06	test-rmse:2.79934e+06
# [50]	train-rmse:2.32769e+06	test-rmse:2.78718e+06
# [51]	train-rmse:2.31129e+06	test-rmse:2.77597e+06
# [52]	train-rmse:2.29652e+06	test-rmse:2.76723e+06
# [53]	train-rmse:2.2837e+06	test-rmse:2.75781e+06
# [54]	train-rmse:2.26996e+06	test-rmse:2.74962e+06
# [55]	train-rmse:2.25649e+06	test-rmse:2.7407e+06
# [56]	train-rmse:2.24468e+06	test-rmse:2.73275e+06
# [57]	train-rmse:2.23375e+06	test-rmse:2.72666e+06
# [58]	train-rmse:2.22202e+06	test-rmse:2.7203e+06
# [59]	train-rmse:2.21239e+06	test-rmse:2.71454e+06
# [60]	train-rmse:2.20278e+06	test-rmse:2.70895e+06
# [61]	train-rmse:2.19315e+06	test-rmse:2.70393e+06
# [62]	train-rmse:2.18448e+06	test-rmse:2.6989e+06
# [63]	train-rmse:2.1754e+06	test-rmse:2.69276e+06
# [64]	train-rmse:2.16816e+06	test-rmse:2.6889e+06
# [65]	train-rmse:2.15966e+06	test-rmse:2.68424e+06
# [66]	train-rmse:2.15122e+06	test-rmse:2.68108e+06
# [67]	train-rmse:2.14437e+06	test-rmse:2.6776e+06
# [68]	train-rmse:2.13789e+06	test-rmse:2.67375e+06
# [69]	train-rmse:2.13189e+06	test-rmse:2.66979e+06
# [70]	train-rmse:2.12604e+06	test-rmse:2.66693e+06
# [71]	train-rmse:2.12103e+06	test-rmse:2.66399e+06
# [72]	train-rmse:2.11585e+06	test-rmse:2.66193e+06
# [73]	train-rmse:2.11137e+06	test-rmse:2.66027e+06
# [74]	train-rmse:2.1063e+06	test-rmse:2.65812e+06
# [75]	train-rmse:2.10079e+06	test-rmse:2.65412e+06
# [76]	train-rmse:2.09566e+06	test-rmse:2.65132e+06
# [77]	train-rmse:2.09081e+06	test-rmse:2.64902e+06
# [78]	train-rmse:2.08647e+06	test-rmse:2.64599e+06
# [79]	train-rmse:2.08102e+06	test-rmse:2.6431e+06
# [80]	train-rmse:2.07551e+06	test-rmse:2.6407e+06
# [81]	train-rmse:2.07097e+06	test-rmse:2.63915e+06
# [82]	train-rmse:2.06572e+06	test-rmse:2.6376e+06
# [83]	train-rmse:2.06197e+06	test-rmse:2.63559e+06
# [84]	train-rmse:2.0577e+06	test-rmse:2.63385e+06
# [85]	train-rmse:2.0554e+06	test-rmse:2.63348e+06
# [86]	train-rmse:2.05156e+06	test-rmse:2.6317e+06
# [87]	train-rmse:2.04659e+06	test-rmse:2.62981e+06
# [88]	train-rmse:2.04342e+06	test-rmse:2.6288e+06
# [89]	train-rmse:2.03887e+06	test-rmse:2.62695e+06
# [90]	train-rmse:2.03502e+06	test-rmse:2.6251e+06
# [91]	train-rmse:2.03177e+06	test-rmse:2.62344e+06
# [92]	train-rmse:2.02782e+06	test-rmse:2.62203e+06
# [93]	train-rmse:2.02354e+06	test-rmse:2.62059e+06
# [94]	train-rmse:2.01999e+06	test-rmse:2.61856e+06
# [95]	train-rmse:2.01723e+06	test-rmse:2.61737e+06
# [96]	train-rmse:2.01399e+06	test-rmse:2.61664e+06
# [97]	train-rmse:2.01081e+06	test-rmse:2.61551e+06
# [98]	train-rmse:2.00773e+06	test-rmse:2.61403e+06
# [99]	train-rmse:2.00503e+06	test-rmse:2.61267e+06
# [100]	train-rmse:2.00274e+06	test-rmse:2.61225e+06
# [101]	train-rmse:2.0005e+06	test-rmse:2.61185e+06
# [102]	train-rmse:1.99801e+06	test-rmse:2.61065e+06
# [103]	train-rmse:1.99443e+06	test-rmse:2.60947e+06
# [104]	train-rmse:1.99163e+06	test-rmse:2.60847e+06
# [105]	train-rmse:1.9895e+06	test-rmse:2.60762e+06
# [106]	train-rmse:1.98756e+06	test-rmse:2.60692e+06
# [107]	train-rmse:1.9848e+06	test-rmse:2.60614e+06
# [108]	train-rmse:1.98123e+06	test-rmse:2.60492e+06
# [109]	train-rmse:1.97827e+06	test-rmse:2.60423e+06
# [110]	train-rmse:1.97588e+06	test-rmse:2.60307e+06
# [111]	train-rmse:1.97309e+06	test-rmse:2.60183e+06
# [112]	train-rmse:1.97019e+06	test-rmse:2.60075e+06
# [113]	train-rmse:1.96765e+06	test-rmse:2.60021e+06
# [114]	train-rmse:1.96543e+06	test-rmse:2.59981e+06
# [115]	train-rmse:1.96321e+06	test-rmse:2.59862e+06
# [116]	train-rmse:1.96117e+06	test-rmse:2.59749e+06
# [117]	train-rmse:1.95849e+06	test-rmse:2.59668e+06
# [118]	train-rmse:1.95676e+06	test-rmse:2.59567e+06
# [119]	train-rmse:1.95382e+06	test-rmse:2.59471e+06
# [120]	train-rmse:1.95092e+06	test-rmse:2.59396e+06
# [121]	train-rmse:1.9488e+06	test-rmse:2.59349e+06
# [122]	train-rmse:1.94702e+06	test-rmse:2.59286e+06
# [123]	train-rmse:1.94467e+06	test-rmse:2.59221e+06
# [124]	train-rmse:1.94199e+06	test-rmse:2.59148e+06
# [125]	train-rmse:1.93965e+06	test-rmse:2.59073e+06
# [126]	train-rmse:1.93804e+06	test-rmse:2.59014e+06
# [127]	train-rmse:1.93519e+06	test-rmse:2.58897e+06
# [128]	train-rmse:1.93309e+06	test-rmse:2.58845e+06
# [129]	train-rmse:1.93114e+06	test-rmse:2.5879e+06
# [130]	train-rmse:1.92842e+06	test-rmse:2.58719e+06
# [131]	train-rmse:1.92675e+06	test-rmse:2.58686e+06
# [132]	train-rmse:1.92441e+06	test-rmse:2.58593e+06
# [133]	train-rmse:1.92251e+06	test-rmse:2.58542e+06
# [134]	train-rmse:1.92036e+06	test-rmse:2.58476e+06
# [135]	train-rmse:1.91639e+06	test-rmse:2.58338e+06
# [136]	train-rmse:1.9142e+06	test-rmse:2.58219e+06
# [137]	train-rmse:1.91139e+06	test-rmse:2.58131e+06
# [138]	train-rmse:1.90914e+06	test-rmse:2.58085e+06
# [139]	train-rmse:1.90726e+06	test-rmse:2.58068e+06
# [140]	train-rmse:1.90496e+06	test-rmse:2.57977e+06
# [141]	train-rmse:1.90263e+06	test-rmse:2.57908e+06
# [142]	train-rmse:1.90078e+06	test-rmse:2.57876e+06
# [143]	train-rmse:1.89942e+06	test-rmse:2.57828e+06
# [144]	train-rmse:1.89715e+06	test-rmse:2.5779e+06
# [145]	train-rmse:1.8948e+06	test-rmse:2.57734e+06
# [146]	train-rmse:1.89273e+06	test-rmse:2.57704e+06
# [147]	train-rmse:1.89063e+06	test-rmse:2.57682e+06
# [148]	train-rmse:1.8884e+06	test-rmse:2.57627e+06
# [149]	train-rmse:1.88543e+06	test-rmse:2.57585e+06
# [150]	train-rmse:1.88374e+06	test-rmse:2.57537e+06
# [151]	train-rmse:1.88116e+06	test-rmse:2.57479e+06
# [152]	train-rmse:1.87827e+06	test-rmse:2.57408e+06
# [153]	train-rmse:1.87603e+06	test-rmse:2.57392e+06
# [154]	train-rmse:1.8741e+06	test-rmse:2.57384e+06
# [155]	train-rmse:1.87166e+06	test-rmse:2.57304e+06
# [156]	train-rmse:1.86959e+06	test-rmse:2.5728e+06
# [157]	train-rmse:1.8673e+06	test-rmse:2.57217e+06
# [158]	train-rmse:1.86532e+06	test-rmse:2.57213e+06
# [159]	train-rmse:1.86358e+06	test-rmse:2.57168e+06
# [160]	train-rmse:1.86135e+06	test-rmse:2.57101e+06
# [161]	train-rmse:1.85882e+06	test-rmse:2.5707e+06
# [162]	train-rmse:1.85757e+06	test-rmse:2.57014e+06
# [163]	train-rmse:1.85492e+06	test-rmse:2.56969e+06
# [164]	train-rmse:1.85261e+06	test-rmse:2.56927e+06
# [165]	train-rmse:1.8506e+06	test-rmse:2.56955e+06
# [166]	train-rmse:1.8491e+06	test-rmse:2.5692e+06
# [167]	train-rmse:1.84584e+06	test-rmse:2.56879e+06
# [168]	train-rmse:1.84412e+06	test-rmse:2.56876e+06
# [169]	train-rmse:1.84033e+06	test-rmse:2.56748e+06
# [170]	train-rmse:1.83832e+06	test-rmse:2.56743e+06
# [171]	train-rmse:1.83623e+06	test-rmse:2.56706e+06
# [172]	train-rmse:1.83361e+06	test-rmse:2.56655e+06
# [173]	train-rmse:1.8308e+06	test-rmse:2.5663e+06
# [174]	train-rmse:1.82893e+06	test-rmse:2.56589e+06
# [175]	train-rmse:1.82717e+06	test-rmse:2.56584e+06
# [176]	train-rmse:1.8247e+06	test-rmse:2.56555e+06
# [177]	train-rmse:1.82246e+06	test-rmse:2.5653e+06
# [178]	train-rmse:1.82e+06	test-rmse:2.56526e+06
# [179]	train-rmse:1.81793e+06	test-rmse:2.56491e+06
# [180]	train-rmse:1.81599e+06	test-rmse:2.56423e+06
# [181]	train-rmse:1.81461e+06	test-rmse:2.56384e+06
# [182]	train-rmse:1.81387e+06	test-rmse:2.56368e+06
# [183]	train-rmse:1.81117e+06	test-rmse:2.56315e+06
# [184]	train-rmse:1.80896e+06	test-rmse:2.56302e+06
# [185]	train-rmse:1.80639e+06	test-rmse:2.56232e+06
# [186]	train-rmse:1.8036e+06	test-rmse:2.56187e+06
# [187]	train-rmse:1.80203e+06	test-rmse:2.56159e+06
# [188]	train-rmse:1.79907e+06	test-rmse:2.56081e+06
# [189]	train-rmse:1.79682e+06	test-rmse:2.5606e+06
# [190]	train-rmse:1.7952e+06	test-rmse:2.56044e+06
# [191]	train-rmse:1.79223e+06	test-rmse:2.5603e+06
# [192]	train-rmse:1.78935e+06	test-rmse:2.5598e+06
# [193]	train-rmse:1.78803e+06	test-rmse:2.55963e+06
# [194]	train-rmse:1.78562e+06	test-rmse:2.5592e+06
# [195]	train-rmse:1.78404e+06	test-rmse:2.55887e+06
# [196]	train-rmse:1.78236e+06	test-rmse:2.55862e+06
# [197]	train-rmse:1.78001e+06	test-rmse:2.55853e+06
# [198]	train-rmse:1.77745e+06	test-rmse:2.55819e+06
# [199]	train-rmse:1.77615e+06	test-rmse:2.55808e+06
# [200]	train-rmse:1.7736e+06	test-rmse:2.55792e+06
# [201]	train-rmse:1.77199e+06	test-rmse:2.55764e+06
# [202]	train-rmse:1.7698e+06	test-rmse:2.55741e+06
# [203]	train-rmse:1.76761e+06	test-rmse:2.55738e+06
# [204]	train-rmse:1.76522e+06	test-rmse:2.55671e+06
# [205]	train-rmse:1.76336e+06	test-rmse:2.55676e+06
# [206]	train-rmse:1.76158e+06	test-rmse:2.55679e+06
# [207]	train-rmse:1.75947e+06	test-rmse:2.55666e+06
# [208]	train-rmse:1.75724e+06	test-rmse:2.55635e+06
# [209]	train-rmse:1.75561e+06	test-rmse:2.5561e+06
# [210]	train-rmse:1.75295e+06	test-rmse:2.55563e+06
# [211]	train-rmse:1.75154e+06	test-rmse:2.55539e+06
# [212]	train-rmse:1.75015e+06	test-rmse:2.55527e+06
# [213]	train-rmse:1.7486e+06	test-rmse:2.55507e+06
# [214]	train-rmse:1.74666e+06	test-rmse:2.55481e+06
# [215]	train-rmse:1.74495e+06	test-rmse:2.55462e+06
# [216]	train-rmse:1.74331e+06	test-rmse:2.55441e+06
# [217]	train-rmse:1.74123e+06	test-rmse:2.55389e+06
# [218]	train-rmse:1.73806e+06	test-rmse:2.55344e+06
# [219]	train-rmse:1.73632e+06	test-rmse:2.55373e+06
# [220]	train-rmse:1.7348e+06	test-rmse:2.55346e+06
# [221]	train-rmse:1.7331e+06	test-rmse:2.55318e+06
# [222]	train-rmse:1.73142e+06	test-rmse:2.55281e+06
# [223]	train-rmse:1.72984e+06	test-rmse:2.55252e+06
# [224]	train-rmse:1.72731e+06	test-rmse:2.55182e+06
# [225]	train-rmse:1.72585e+06	test-rmse:2.55136e+06
# [226]	train-rmse:1.72418e+06	test-rmse:2.55112e+06
# [227]	train-rmse:1.72273e+06	test-rmse:2.55082e+06
# [228]	train-rmse:1.72127e+06	test-rmse:2.55052e+06
# [229]	train-rmse:1.71901e+06	test-rmse:2.55024e+06
# [230]	train-rmse:1.71799e+06	test-rmse:2.54998e+06
# [231]	train-rmse:1.71629e+06	test-rmse:2.54999e+06
# [232]	train-rmse:1.71481e+06	test-rmse:2.54982e+06
# [233]	train-rmse:1.71279e+06	test-rmse:2.54942e+06
# [234]	train-rmse:1.71123e+06	test-rmse:2.54956e+06
# [235]	train-rmse:1.70916e+06	test-rmse:2.54883e+06
# [236]	train-rmse:1.7071e+06	test-rmse:2.54833e+06
# [237]	train-rmse:1.70556e+06	test-rmse:2.54824e+06
# [238]	train-rmse:1.70412e+06	test-rmse:2.54823e+06
# [239]	train-rmse:1.70302e+06	test-rmse:2.54787e+06
# [240]	train-rmse:1.70057e+06	test-rmse:2.54774e+06
# [241]	train-rmse:1.69888e+06	test-rmse:2.54762e+06
# [242]	train-rmse:1.69764e+06	test-rmse:2.54732e+06
# [243]	train-rmse:1.69568e+06	test-rmse:2.54729e+06
# [244]	train-rmse:1.69373e+06	test-rmse:2.54685e+06
# [245]	train-rmse:1.69269e+06	test-rmse:2.54687e+06
# [246]	train-rmse:1.69126e+06	test-rmse:2.54683e+06
# [247]	train-rmse:1.68946e+06	test-rmse:2.54651e+06
# [248]	train-rmse:1.68677e+06	test-rmse:2.54648e+06
# [249]	train-rmse:1.68519e+06	test-rmse:2.54661e+06
# [250]	train-rmse:1.68389e+06	test-rmse:2.54651e+06
# [251]	train-rmse:1.682e+06	test-rmse:2.5461e+06
# [252]	train-rmse:1.68022e+06	test-rmse:2.54624e+06
# [253]	train-rmse:1.6789e+06	test-rmse:2.54629e+06
# [254]	train-rmse:1.67703e+06	test-rmse:2.54589e+06
# [255]	train-rmse:1.67517e+06	test-rmse:2.5458e+06
# [256]	train-rmse:1.67312e+06	test-rmse:2.54561e+06
# [257]	train-rmse:1.67132e+06	test-rmse:2.54515e+06
# [258]	train-rmse:1.67014e+06	test-rmse:2.54531e+06
# [259]	train-rmse:1.66894e+06	test-rmse:2.54515e+06
# [260]	train-rmse:1.66744e+06	test-rmse:2.54524e+06
# [261]	train-rmse:1.66601e+06	test-rmse:2.5453e+06
# [262]	train-rmse:1.66458e+06	test-rmse:2.54523e+06
# [263]	train-rmse:1.66338e+06	test-rmse:2.54522e+06
# [264]	train-rmse:1.66137e+06	test-rmse:2.54479e+06
# [265]	train-rmse:1.65914e+06	test-rmse:2.54462e+06
# [266]	train-rmse:1.65771e+06	test-rmse:2.54443e+06
# [267]	train-rmse:1.65618e+06	test-rmse:2.54435e+06
# [268]	train-rmse:1.65445e+06	test-rmse:2.5443e+06
# [269]	train-rmse:1.65344e+06	test-rmse:2.54435e+06
# [270]	train-rmse:1.65232e+06	test-rmse:2.54446e+06
# [271]	train-rmse:1.65057e+06	test-rmse:2.54448e+06
# [272]	train-rmse:1.64972e+06	test-rmse:2.54469e+06
# [273]	train-rmse:1.64822e+06	test-rmse:2.54456e+06
# [274]	train-rmse:1.64631e+06	test-rmse:2.54457e+06
# [275]	train-rmse:1.64422e+06	test-rmse:2.54454e+06
# [276]	train-rmse:1.64193e+06	test-rmse:2.54427e+06
# [277]	train-rmse:1.64003e+06	test-rmse:2.54474e+06
# [278]	train-rmse:1.63865e+06	test-rmse:2.54455e+06
# [279]	train-rmse:1.63694e+06	test-rmse:2.54447e+06
# [280]	train-rmse:1.63507e+06	test-rmse:2.54423e+06
# [281]	train-rmse:1.63397e+06	test-rmse:2.5445e+06
# [282]	train-rmse:1.63292e+06	test-rmse:2.54445e+06
# [283]	train-rmse:1.63114e+06	test-rmse:2.54435e+06
# [284]	train-rmse:1.62925e+06	test-rmse:2.54418e+06
# [285]	train-rmse:1.6279e+06	test-rmse:2.54417e+06
# [286]	train-rmse:1.62655e+06	test-rmse:2.54409e+06
# [287]	train-rmse:1.62407e+06	test-rmse:2.54415e+06
# [288]	train-rmse:1.62211e+06	test-rmse:2.544e+06
# [289]	train-rmse:1.62053e+06	test-rmse:2.54383e+06
# [290]	train-rmse:1.6191e+06	test-rmse:2.5436e+06
# [291]	train-rmse:1.61711e+06	test-rmse:2.54335e+06
# [292]	train-rmse:1.61581e+06	test-rmse:2.54351e+06
# [293]	train-rmse:1.61484e+06	test-rmse:2.54379e+06
# [294]	train-rmse:1.61332e+06	test-rmse:2.54374e+06
# [295]	train-rmse:1.61176e+06	test-rmse:2.54368e+06
# [296]	train-rmse:1.61054e+06	test-rmse:2.54357e+06
# [297]	train-rmse:1.6093e+06	test-rmse:2.5435e+06
# [298]	train-rmse:1.60789e+06	test-rmse:2.54337e+06
# [299]	train-rmse:1.60655e+06	test-rmse:2.54354e+06
# [300]	train-rmse:1.60576e+06	test-rmse:2.54372e+06

# %%
len(cv_output)
# Out:
# 292

# %%
num_boost_rounds = len(cv_output) #422
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_rounds)

# %%
y_predict = model.predict(dtest)

# %%
gunja_output = pd.DataFrame({'id': id_test, 'price_doc': y_predict})

# %%
gunja_output.to_csv('gunja_output_June22.csv',index=False)

# %%
#######################################

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
id_test = test.id

# %%
#train = train[train['kremlin_km']>=0.1]

# %%
mult = .969

y_train = train["price_doc"] * mult + 10
x_train = train.drop(["id", "timestamp", "price_doc"], axis=1)
x_test = test.drop(["id", "timestamp"], axis=1)

for c in x_train.columns:
    if x_train[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_train[c].values))
        x_train[c] = lbl.transform(list(x_train[c].values))

for c in x_test.columns:
    if x_test[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_test[c].values))
        x_test[c] = lbl.transform(list(x_test[c].values))

# %%
xgb_params = {
    'eta': 0.05,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test)

# %%
cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=500, early_stopping_rounds=10,
    verbose_eval=1, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
# Out:
# [0]	train-rmse:7.95155e+06	test-rmse:7.95419e+06
# [1]	train-rmse:7.61888e+06	test-rmse:7.62639e+06
# [2]	train-rmse:7.29625e+06	test-rmse:7.3086e+06
# [3]	train-rmse:6.99818e+06	test-rmse:7.01626e+06
# [4]	train-rmse:6.72226e+06	test-rmse:6.74537e+06
# [5]	train-rmse:6.45039e+06	test-rmse:6.47707e+06
# [6]	train-rmse:6.19549e+06	test-rmse:6.23032e+06
# [7]	train-rmse:5.95624e+06	test-rmse:6.00024e+06
# [8]	train-rmse:5.7292e+06	test-rmse:5.78049e+06
# [9]	train-rmse:5.51193e+06	test-rmse:5.5696e+06
# [10]	train-rmse:5.31184e+06	test-rmse:5.37577e+06
# [11]	train-rmse:5.11895e+06	test-rmse:5.18869e+06
# [12]	train-rmse:4.94237e+06	test-rmse:5.01888e+06
# [13]	train-rmse:4.7724e+06	test-rmse:4.85529e+06
# [14]	train-rmse:4.61209e+06	test-rmse:4.70258e+06
# [15]	train-rmse:4.46221e+06	test-rmse:4.5609e+06
# [16]	train-rmse:4.3205e+06	test-rmse:4.42597e+06
# [17]	train-rmse:4.18713e+06	test-rmse:4.29939e+06
# [18]	train-rmse:4.06277e+06	test-rmse:4.18262e+06
# [19]	train-rmse:3.94431e+06	test-rmse:4.07238e+06
# [20]	train-rmse:3.83632e+06	test-rmse:3.97373e+06
# [21]	train-rmse:3.73131e+06	test-rmse:3.87715e+06
# [22]	train-rmse:3.63401e+06	test-rmse:3.78795e+06
# [23]	train-rmse:3.54261e+06	test-rmse:3.70503e+06
# [24]	train-rmse:3.46067e+06	test-rmse:3.63221e+06
# [25]	train-rmse:3.38336e+06	test-rmse:3.56379e+06
# [26]	train-rmse:3.31209e+06	test-rmse:3.50124e+06
# [27]	train-rmse:3.24267e+06	test-rmse:3.4389e+06
# [28]	train-rmse:3.17691e+06	test-rmse:3.37909e+06
# [29]	train-rmse:3.11781e+06	test-rmse:3.3276e+06
# [30]	train-rmse:3.06128e+06	test-rmse:3.28036e+06
# [31]	train-rmse:3.01077e+06	test-rmse:3.2373e+06
# [32]	train-rmse:2.96169e+06	test-rmse:3.19553e+06
# [33]	train-rmse:2.91534e+06	test-rmse:3.1565e+06
# [34]	train-rmse:2.87004e+06	test-rmse:3.12253e+06
# [35]	train-rmse:2.82971e+06	test-rmse:3.0887e+06
# [36]	train-rmse:2.79267e+06	test-rmse:3.05774e+06
# [37]	train-rmse:2.75581e+06	test-rmse:3.0288e+06
# [38]	train-rmse:2.72248e+06	test-rmse:3.00252e+06
# [39]	train-rmse:2.69136e+06	test-rmse:2.97893e+06
# [40]	train-rmse:2.6645e+06	test-rmse:2.95753e+06
# [41]	train-rmse:2.63739e+06	test-rmse:2.93576e+06
# [42]	train-rmse:2.61166e+06	test-rmse:2.91659e+06
# [43]	train-rmse:2.587e+06	test-rmse:2.89657e+06
# [44]	train-rmse:2.56285e+06	test-rmse:2.87915e+06
# [45]	train-rmse:2.54168e+06	test-rmse:2.8638e+06
# [46]	train-rmse:2.52188e+06	test-rmse:2.84845e+06
# [47]	train-rmse:2.50257e+06	test-rmse:2.83516e+06
# [48]	train-rmse:2.48426e+06	test-rmse:2.82377e+06
# [49]	train-rmse:2.46596e+06	test-rmse:2.81256e+06
# [50]	train-rmse:2.44939e+06	test-rmse:2.80112e+06
# [51]	train-rmse:2.43473e+06	test-rmse:2.79091e+06
# [52]	train-rmse:2.42148e+06	test-rmse:2.78183e+06
# [53]	train-rmse:2.40605e+06	test-rmse:2.77287e+06
# [54]	train-rmse:2.3919e+06	test-rmse:2.76386e+06
# [55]	train-rmse:2.3794e+06	test-rmse:2.75693e+06
# [56]	train-rmse:2.36646e+06	test-rmse:2.74881e+06
# [57]	train-rmse:2.35663e+06	test-rmse:2.74229e+06
# [58]	train-rmse:2.34451e+06	test-rmse:2.7352e+06
# [59]	train-rmse:2.33422e+06	test-rmse:2.72843e+06
# [60]	train-rmse:2.32384e+06	test-rmse:2.72212e+06
# [61]	train-rmse:2.31734e+06	test-rmse:2.71785e+06
# [62]	train-rmse:2.30887e+06	test-rmse:2.71263e+06
# [63]	train-rmse:2.30014e+06	test-rmse:2.707e+06
# [64]	train-rmse:2.29329e+06	test-rmse:2.7025e+06
# [65]	train-rmse:2.28494e+06	test-rmse:2.69796e+06
# [66]	train-rmse:2.27794e+06	test-rmse:2.69523e+06
# [67]	train-rmse:2.27103e+06	test-rmse:2.69156e+06
# [68]	train-rmse:2.26449e+06	test-rmse:2.68787e+06
# [69]	train-rmse:2.25866e+06	test-rmse:2.68426e+06
# [70]	train-rmse:2.25312e+06	test-rmse:2.68128e+06
# [71]	train-rmse:2.24726e+06	test-rmse:2.67705e+06
# [72]	train-rmse:2.24309e+06	test-rmse:2.67488e+06
# [73]	train-rmse:2.23764e+06	test-rmse:2.67184e+06
# [74]	train-rmse:2.23004e+06	test-rmse:2.66925e+06
# [75]	train-rmse:2.22586e+06	test-rmse:2.667e+06
# [76]	train-rmse:2.22071e+06	test-rmse:2.66517e+06
# [77]	train-rmse:2.2161e+06	test-rmse:2.66257e+06
# [78]	train-rmse:2.21163e+06	test-rmse:2.66106e+06
# [79]	train-rmse:2.20583e+06	test-rmse:2.65792e+06
# [80]	train-rmse:2.20065e+06	test-rmse:2.65524e+06
# [81]	train-rmse:2.19502e+06	test-rmse:2.65258e+06
# [82]	train-rmse:2.18909e+06	test-rmse:2.65091e+06
# [83]	train-rmse:2.18459e+06	test-rmse:2.64864e+06
# [84]	train-rmse:2.18041e+06	test-rmse:2.64727e+06
# [85]	train-rmse:2.17578e+06	test-rmse:2.64509e+06
# [86]	train-rmse:2.17078e+06	test-rmse:2.64415e+06
# [87]	train-rmse:2.16729e+06	test-rmse:2.64248e+06
# [88]	train-rmse:2.1633e+06	test-rmse:2.63937e+06
# [89]	train-rmse:2.16038e+06	test-rmse:2.63811e+06
# [90]	train-rmse:2.1572e+06	test-rmse:2.63659e+06
# [91]	train-rmse:2.15339e+06	test-rmse:2.6351e+06
# [92]	train-rmse:2.15025e+06	test-rmse:2.63416e+06
# [93]	train-rmse:2.14682e+06	test-rmse:2.6315e+06
# [94]	train-rmse:2.14258e+06	test-rmse:2.62955e+06
# [95]	train-rmse:2.13958e+06	test-rmse:2.62843e+06
# [96]	train-rmse:2.13675e+06	test-rmse:2.62739e+06
# [97]	train-rmse:2.1341e+06	test-rmse:2.62615e+06
# [98]	train-rmse:2.13065e+06	test-rmse:2.62402e+06
# [99]	train-rmse:2.12758e+06	test-rmse:2.62321e+06
# [100]	train-rmse:2.12475e+06	test-rmse:2.62177e+06
# [101]	train-rmse:2.12143e+06	test-rmse:2.62063e+06
# [102]	train-rmse:2.11885e+06	test-rmse:2.62005e+06
# [103]	train-rmse:2.11516e+06	test-rmse:2.61965e+06
# [104]	train-rmse:2.11267e+06	test-rmse:2.6186e+06
# [105]	train-rmse:2.10984e+06	test-rmse:2.61679e+06
# [106]	train-rmse:2.10706e+06	test-rmse:2.61589e+06
# [107]	train-rmse:2.10425e+06	test-rmse:2.61505e+06
# [108]	train-rmse:2.1026e+06	test-rmse:2.61455e+06
# [109]	train-rmse:2.10023e+06	test-rmse:2.61359e+06
# [110]	train-rmse:2.09725e+06	test-rmse:2.61264e+06
# [111]	train-rmse:2.09501e+06	test-rmse:2.61202e+06
# [112]	train-rmse:2.0923e+06	test-rmse:2.61131e+06
# [113]	train-rmse:2.09015e+06	test-rmse:2.61077e+06
# [114]	train-rmse:2.08734e+06	test-rmse:2.60981e+06
# [115]	train-rmse:2.08471e+06	test-rmse:2.60907e+06
# [116]	train-rmse:2.08293e+06	test-rmse:2.60858e+06
# [117]	train-rmse:2.08122e+06	test-rmse:2.60825e+06
# [118]	train-rmse:2.07808e+06	test-rmse:2.60731e+06
# [119]	train-rmse:2.07645e+06	test-rmse:2.60719e+06
# [120]	train-rmse:2.07423e+06	test-rmse:2.60611e+06
# [121]	train-rmse:2.07068e+06	test-rmse:2.60459e+06
# [122]	train-rmse:2.06899e+06	test-rmse:2.60396e+06
# [123]	train-rmse:2.06642e+06	test-rmse:2.60311e+06
# [124]	train-rmse:2.06486e+06	test-rmse:2.60255e+06
# [125]	train-rmse:2.06237e+06	test-rmse:2.60187e+06
# [126]	train-rmse:2.06074e+06	test-rmse:2.60132e+06
# [127]	train-rmse:2.05831e+06	test-rmse:2.60087e+06
# [128]	train-rmse:2.05612e+06	test-rmse:2.60036e+06
# [129]	train-rmse:2.05421e+06	test-rmse:2.59983e+06
# [130]	train-rmse:2.05188e+06	test-rmse:2.59911e+06
# [131]	train-rmse:2.04953e+06	test-rmse:2.59873e+06
# [132]	train-rmse:2.04591e+06	test-rmse:2.5977e+06
# [133]	train-rmse:2.04393e+06	test-rmse:2.59676e+06
# [134]	train-rmse:2.04235e+06	test-rmse:2.59671e+06
# [135]	train-rmse:2.03938e+06	test-rmse:2.59562e+06
# [136]	train-rmse:2.0357e+06	test-rmse:2.59443e+06
# [137]	train-rmse:2.03434e+06	test-rmse:2.59422e+06
# [138]	train-rmse:2.03219e+06	test-rmse:2.59352e+06
# [139]	train-rmse:2.03045e+06	test-rmse:2.59326e+06
# [140]	train-rmse:2.02846e+06	test-rmse:2.59242e+06
# [141]	train-rmse:2.02707e+06	test-rmse:2.59187e+06
# [142]	train-rmse:2.02553e+06	test-rmse:2.5909e+06
# [143]	train-rmse:2.02206e+06	test-rmse:2.59064e+06
# [144]	train-rmse:2.02013e+06	test-rmse:2.5902e+06
# [145]	train-rmse:2.01841e+06	test-rmse:2.58972e+06
# [146]	train-rmse:2.01666e+06	test-rmse:2.58943e+06
# [147]	train-rmse:2.01414e+06	test-rmse:2.58961e+06
# [148]	train-rmse:2.01253e+06	test-rmse:2.58919e+06
# [149]	train-rmse:2.01062e+06	test-rmse:2.58833e+06
# [150]	train-rmse:2.00876e+06	test-rmse:2.58752e+06
# [151]	train-rmse:2.00726e+06	test-rmse:2.5873e+06
# [152]	train-rmse:2.00528e+06	test-rmse:2.58659e+06
# [153]	train-rmse:2.0034e+06	test-rmse:2.586e+06
# [154]	train-rmse:2.00094e+06	test-rmse:2.58498e+06
# [155]	train-rmse:1.99954e+06	test-rmse:2.58453e+06
# [156]	train-rmse:1.99719e+06	test-rmse:2.58413e+06
# [157]	train-rmse:1.99577e+06	test-rmse:2.58357e+06
# [158]	train-rmse:1.99448e+06	test-rmse:2.5832e+06
# [159]	train-rmse:1.99248e+06	test-rmse:2.58315e+06
# [160]	train-rmse:1.99088e+06	test-rmse:2.583e+06
# [161]	train-rmse:1.98878e+06	test-rmse:2.58292e+06
# [162]	train-rmse:1.9876e+06	test-rmse:2.58273e+06
# [163]	train-rmse:1.98535e+06	test-rmse:2.58199e+06
# [164]	train-rmse:1.98373e+06	test-rmse:2.58156e+06
# [165]	train-rmse:1.98173e+06	test-rmse:2.58089e+06
# [166]	train-rmse:1.98006e+06	test-rmse:2.58006e+06
# [167]	train-rmse:1.97772e+06	test-rmse:2.57923e+06
# [168]	train-rmse:1.97675e+06	test-rmse:2.57878e+06
# [169]	train-rmse:1.97456e+06	test-rmse:2.57846e+06
# [170]	train-rmse:1.97319e+06	test-rmse:2.57844e+06
# [171]	train-rmse:1.97145e+06	test-rmse:2.57793e+06
# [172]	train-rmse:1.96977e+06	test-rmse:2.57777e+06
# [173]	train-rmse:1.96778e+06	test-rmse:2.57743e+06
# [174]	train-rmse:1.9661e+06	test-rmse:2.57741e+06
# [175]	train-rmse:1.96472e+06	test-rmse:2.57693e+06
# [176]	train-rmse:1.96223e+06	test-rmse:2.57669e+06
# [177]	train-rmse:1.96035e+06	test-rmse:2.57603e+06
# [178]	train-rmse:1.95868e+06	test-rmse:2.57563e+06
# [179]	train-rmse:1.95704e+06	test-rmse:2.57499e+06
# [180]	train-rmse:1.9551e+06	test-rmse:2.57423e+06
# [181]	train-rmse:1.95374e+06	test-rmse:2.57412e+06
# [182]	train-rmse:1.95302e+06	test-rmse:2.57366e+06
# [183]	train-rmse:1.95174e+06	test-rmse:2.57319e+06
# [184]	train-rmse:1.94924e+06	test-rmse:2.57213e+06
# [185]	train-rmse:1.94746e+06	test-rmse:2.5717e+06
# [186]	train-rmse:1.94607e+06	test-rmse:2.57144e+06
# [187]	train-rmse:1.94402e+06	test-rmse:2.57144e+06
# [188]	train-rmse:1.94286e+06	test-rmse:2.57108e+06
# [189]	train-rmse:1.942e+06	test-rmse:2.57085e+06
# [190]	train-rmse:1.9408e+06	test-rmse:2.57071e+06
# [191]	train-rmse:1.93865e+06	test-rmse:2.57005e+06
# [192]	train-rmse:1.93651e+06	test-rmse:2.56971e+06
# [193]	train-rmse:1.93488e+06	test-rmse:2.56929e+06
# [194]	train-rmse:1.9339e+06	test-rmse:2.56919e+06
# [195]	train-rmse:1.93236e+06	test-rmse:2.56865e+06
# [196]	train-rmse:1.9306e+06	test-rmse:2.5679e+06
# [197]	train-rmse:1.92805e+06	test-rmse:2.56767e+06
# [198]	train-rmse:1.92687e+06	test-rmse:2.56739e+06
# [199]	train-rmse:1.92487e+06	test-rmse:2.5668e+06
# [200]	train-rmse:1.92402e+06	test-rmse:2.56628e+06
# [201]	train-rmse:1.92283e+06	test-rmse:2.56635e+06
# [202]	train-rmse:1.92123e+06	test-rmse:2.56578e+06
# [203]	train-rmse:1.91995e+06	test-rmse:2.56593e+06
# [204]	train-rmse:1.9187e+06	test-rmse:2.56572e+06
# [205]	train-rmse:1.91748e+06	test-rmse:2.56523e+06
# [206]	train-rmse:1.91636e+06	test-rmse:2.565e+06
# [207]	train-rmse:1.91525e+06	test-rmse:2.56528e+06
# [208]	train-rmse:1.91337e+06	test-rmse:2.56514e+06
# [209]	train-rmse:1.91133e+06	test-rmse:2.56471e+06
# [210]	train-rmse:1.90999e+06	test-rmse:2.56425e+06
# [211]	train-rmse:1.90888e+06	test-rmse:2.56414e+06
# [212]	train-rmse:1.90704e+06	test-rmse:2.56478e+06
# [213]	train-rmse:1.90517e+06	test-rmse:2.5642e+06
# [214]	train-rmse:1.90367e+06	test-rmse:2.56387e+06
# [215]	train-rmse:1.90197e+06	test-rmse:2.56364e+06
# [216]	train-rmse:1.90059e+06	test-rmse:2.56325e+06
# [217]	train-rmse:1.89933e+06	test-rmse:2.5633e+06
# [218]	train-rmse:1.89834e+06	test-rmse:2.56299e+06
# [219]	train-rmse:1.89704e+06	test-rmse:2.56268e+06
# [220]	train-rmse:1.896e+06	test-rmse:2.56278e+06
# [221]	train-rmse:1.895e+06	test-rmse:2.56284e+06
# [222]	train-rmse:1.89353e+06	test-rmse:2.56266e+06
# [223]	train-rmse:1.89259e+06	test-rmse:2.56241e+06
# [224]	train-rmse:1.89111e+06	test-rmse:2.56253e+06
# [225]	train-rmse:1.88967e+06	test-rmse:2.56213e+06
# [226]	train-rmse:1.88868e+06	test-rmse:2.56192e+06
# [227]	train-rmse:1.88733e+06	test-rmse:2.56151e+06
# [228]	train-rmse:1.88641e+06	test-rmse:2.5613e+06
# [229]	train-rmse:1.88542e+06	test-rmse:2.56117e+06
# [230]	train-rmse:1.88323e+06	test-rmse:2.5606e+06
# [231]	train-rmse:1.88225e+06	test-rmse:2.56071e+06
# [232]	train-rmse:1.88134e+06	test-rmse:2.56036e+06
# [233]	train-rmse:1.8801e+06	test-rmse:2.5604e+06
# [234]	train-rmse:1.8786e+06	test-rmse:2.56022e+06
# [235]	train-rmse:1.87747e+06	test-rmse:2.56003e+06
# [236]	train-rmse:1.87603e+06	test-rmse:2.55976e+06
# [237]	train-rmse:1.87529e+06	test-rmse:2.55976e+06
# [238]	train-rmse:1.87445e+06	test-rmse:2.55969e+06
# [239]	train-rmse:1.87336e+06	test-rmse:2.55952e+06
# [240]	train-rmse:1.87241e+06	test-rmse:2.55961e+06
# [241]	train-rmse:1.871e+06	test-rmse:2.55938e+06
# [242]	train-rmse:1.86931e+06	test-rmse:2.55933e+06
# [243]	train-rmse:1.86823e+06	test-rmse:2.55922e+06
# [244]	train-rmse:1.86629e+06	test-rmse:2.55888e+06
# [245]	train-rmse:1.86557e+06	test-rmse:2.55868e+06
# [246]	train-rmse:1.86382e+06	test-rmse:2.55828e+06
# [247]	train-rmse:1.86272e+06	test-rmse:2.55822e+06
# [248]	train-rmse:1.86157e+06	test-rmse:2.55793e+06
# [249]	train-rmse:1.86055e+06	test-rmse:2.5578e+06
# [250]	train-rmse:1.85865e+06	test-rmse:2.55796e+06
# [251]	train-rmse:1.85766e+06	test-rmse:2.55774e+06
# [252]	train-rmse:1.85696e+06	test-rmse:2.55778e+06
# [253]	train-rmse:1.85599e+06	test-rmse:2.55778e+06
# [254]	train-rmse:1.85494e+06	test-rmse:2.55767e+06
# [255]	train-rmse:1.85369e+06	test-rmse:2.55746e+06
# [256]	train-rmse:1.85228e+06	test-rmse:2.55729e+06
# [257]	train-rmse:1.85057e+06	test-rmse:2.5574e+06
# [258]	train-rmse:1.8492e+06	test-rmse:2.55713e+06
# [259]	train-rmse:1.84826e+06	test-rmse:2.5567e+06
# [260]	train-rmse:1.84636e+06	test-rmse:2.55648e+06
# [261]	train-rmse:1.84552e+06	test-rmse:2.55632e+06
# [262]	train-rmse:1.84452e+06	test-rmse:2.55635e+06
# [263]	train-rmse:1.84305e+06	test-rmse:2.55621e+06
# [264]	train-rmse:1.84146e+06	test-rmse:2.55626e+06
# [265]	train-rmse:1.84053e+06	test-rmse:2.55611e+06
# [266]	train-rmse:1.83939e+06	test-rmse:2.55579e+06
# [267]	train-rmse:1.83801e+06	test-rmse:2.55564e+06
# [268]	train-rmse:1.83679e+06	test-rmse:2.55526e+06
# [269]	train-rmse:1.83576e+06	test-rmse:2.55514e+06
# [270]	train-rmse:1.83419e+06	test-rmse:2.55459e+06
# [271]	train-rmse:1.8333e+06	test-rmse:2.55439e+06
# [272]	train-rmse:1.83186e+06	test-rmse:2.55449e+06
# [273]	train-rmse:1.83044e+06	test-rmse:2.55434e+06
# [274]	train-rmse:1.82929e+06	test-rmse:2.55412e+06
# [275]	train-rmse:1.828e+06	test-rmse:2.55374e+06
# [276]	train-rmse:1.82723e+06	test-rmse:2.55354e+06
# [277]	train-rmse:1.82572e+06	test-rmse:2.55355e+06
# [278]	train-rmse:1.82463e+06	test-rmse:2.55341e+06
# [279]	train-rmse:1.82363e+06	test-rmse:2.55349e+06
# [280]	train-rmse:1.82238e+06	test-rmse:2.55337e+06
# [281]	train-rmse:1.82065e+06	test-rmse:2.55275e+06
# [282]	train-rmse:1.82007e+06	test-rmse:2.5527e+06
# [283]	train-rmse:1.81837e+06	test-rmse:2.55244e+06
# [284]	train-rmse:1.81704e+06	test-rmse:2.55225e+06
# [285]	train-rmse:1.81605e+06	test-rmse:2.5522e+06
# [286]	train-rmse:1.81497e+06	test-rmse:2.55188e+06
# [287]	train-rmse:1.81423e+06	test-rmse:2.55175e+06
# [288]	train-rmse:1.8136e+06	test-rmse:2.5516e+06
# [289]	train-rmse:1.81233e+06	test-rmse:2.55158e+06
# [290]	train-rmse:1.81117e+06	test-rmse:2.55155e+06
# [291]	train-rmse:1.8104e+06	test-rmse:2.55152e+06
# [292]	train-rmse:1.80919e+06	test-rmse:2.55197e+06
# [293]	train-rmse:1.80824e+06	test-rmse:2.55184e+06
# [294]	train-rmse:1.80735e+06	test-rmse:2.55178e+06
# [295]	train-rmse:1.80606e+06	test-rmse:2.55184e+06
# [296]	train-rmse:1.80512e+06	test-rmse:2.55151e+06
# [297]	train-rmse:1.80357e+06	test-rmse:2.55132e+06
# [298]	train-rmse:1.80239e+06	test-rmse:2.55091e+06
# [299]	train-rmse:1.80087e+06	test-rmse:2.55077e+06
# [300]	train-rmse:1.79957e+06	test-rmse:2.55048e+06
# [301]	train-rmse:1.79821e+06	test-rmse:2.55029e+06
# [302]	train-rmse:1.79748e+06	test-rmse:2.55026e+06
# [303]	train-rmse:1.79679e+06	test-rmse:2.55041e+06
# [304]	train-rmse:1.79616e+06	test-rmse:2.55032e+06
# [305]	train-rmse:1.79535e+06	test-rmse:2.55007e+06
# [306]	train-rmse:1.79448e+06	test-rmse:2.55008e+06
# [307]	train-rmse:1.79375e+06	test-rmse:2.54984e+06
# [308]	train-rmse:1.79278e+06	test-rmse:2.5497e+06
# [309]	train-rmse:1.79131e+06	test-rmse:2.54948e+06
# [310]	train-rmse:1.79056e+06	test-rmse:2.54937e+06
# [311]	train-rmse:1.78893e+06	test-rmse:2.54922e+06
# [312]	train-rmse:1.78794e+06	test-rmse:2.54901e+06
# [313]	train-rmse:1.78702e+06	test-rmse:2.54913e+06
# [314]	train-rmse:1.78536e+06	test-rmse:2.54926e+06
# [315]	train-rmse:1.78468e+06	test-rmse:2.54931e+06
# [316]	train-rmse:1.7838e+06	test-rmse:2.5492e+06
# [317]	train-rmse:1.78263e+06	test-rmse:2.549e+06
# [318]	train-rmse:1.78156e+06	test-rmse:2.54888e+06
# [319]	train-rmse:1.78018e+06	test-rmse:2.54877e+06
# [320]	train-rmse:1.77937e+06	test-rmse:2.54866e+06
# [321]	train-rmse:1.7782e+06	test-rmse:2.54848e+06
# [322]	train-rmse:1.77717e+06	test-rmse:2.54834e+06
# [323]	train-rmse:1.77661e+06	test-rmse:2.54818e+06
# [324]	train-rmse:1.77589e+06	test-rmse:2.54818e+06
# [325]	train-rmse:1.7747e+06	test-rmse:2.54835e+06
# [326]	train-rmse:1.77359e+06	test-rmse:2.54841e+06
# [327]	train-rmse:1.77219e+06	test-rmse:2.5484e+06
# [328]	train-rmse:1.77077e+06	test-rmse:2.54825e+06
# [329]	train-rmse:1.76949e+06	test-rmse:2.54834e+06
# [330]	train-rmse:1.76866e+06	test-rmse:2.54857e+06
# [331]	train-rmse:1.76787e+06	test-rmse:2.54839e+06
# [332]	train-rmse:1.76698e+06	test-rmse:2.54839e+06
# [333]	train-rmse:1.7657e+06	test-rmse:2.54813e+06
# [334]	train-rmse:1.76464e+06	test-rmse:2.54805e+06
# [335]	train-rmse:1.76366e+06	test-rmse:2.54821e+06
# [336]	train-rmse:1.76269e+06	test-rmse:2.54821e+06
# [337]	train-rmse:1.76204e+06	test-rmse:2.5481e+06
# [338]	train-rmse:1.7612e+06	test-rmse:2.54783e+06
# [339]	train-rmse:1.76017e+06	test-rmse:2.54766e+06
# [340]	train-rmse:1.75902e+06	test-rmse:2.54783e+06
# [341]	train-rmse:1.75819e+06	test-rmse:2.54773e+06
# [342]	train-rmse:1.75727e+06	test-rmse:2.54755e+06
# [343]	train-rmse:1.75646e+06	test-rmse:2.54757e+06
# [344]	train-rmse:1.75513e+06	test-rmse:2.54788e+06
# [345]	train-rmse:1.75446e+06	test-rmse:2.54776e+06
# [346]	train-rmse:1.75345e+06	test-rmse:2.54776e+06
# [347]	train-rmse:1.75244e+06	test-rmse:2.54784e+06
# [348]	train-rmse:1.75131e+06	test-rmse:2.54793e+06
# [349]	train-rmse:1.75009e+06	test-rmse:2.54773e+06
# [350]	train-rmse:1.74943e+06	test-rmse:2.54761e+06
# [351]	train-rmse:1.74817e+06	test-rmse:2.54759e+06
# [352]	train-rmse:1.74731e+06	test-rmse:2.54749e+06
# [353]	train-rmse:1.74676e+06	test-rmse:2.54751e+06
# [354]	train-rmse:1.74584e+06	test-rmse:2.54754e+06
# [355]	train-rmse:1.74456e+06	test-rmse:2.5474e+06
# [356]	train-rmse:1.74362e+06	test-rmse:2.54691e+06
# [357]	train-rmse:1.7425e+06	test-rmse:2.54679e+06
# [358]	train-rmse:1.74183e+06	test-rmse:2.5468e+06
# [359]	train-rmse:1.74107e+06	test-rmse:2.54661e+06
# [360]	train-rmse:1.74038e+06	test-rmse:2.54639e+06
# [361]	train-rmse:1.73974e+06	test-rmse:2.54622e+06
# [362]	train-rmse:1.73834e+06	test-rmse:2.54594e+06
# [363]	train-rmse:1.73743e+06	test-rmse:2.54603e+06
# [364]	train-rmse:1.73649e+06	test-rmse:2.54603e+06
# [365]	train-rmse:1.7357e+06	test-rmse:2.54608e+06
# [366]	train-rmse:1.73505e+06	test-rmse:2.54614e+06
# [367]	train-rmse:1.73397e+06	test-rmse:2.54597e+06
# [368]	train-rmse:1.73266e+06	test-rmse:2.54623e+06
# [369]	train-rmse:1.73163e+06	test-rmse:2.54598e+06
# [370]	train-rmse:1.73037e+06	test-rmse:2.54595e+06
# [371]	train-rmse:1.7293e+06	test-rmse:2.54601e+06

# %%
len(cv_output)
# Out:
# 363

# %%
num_boost_rounds = len(cv_output) #385  # This was the CV output, as earlier version shows
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round= num_boost_rounds)

# %%
y_predict = model.predict(dtest)
output = pd.DataFrame({'id': id_test, 'price_doc': y_predict})

# %%
output.to_csv('louis_June22.csv',index=False)

# %%
##############################################

# %%
df_train = pd.read_csv("train.csv", parse_dates=['timestamp'])
df_test = pd.read_csv("test.csv", parse_dates=['timestamp'])
df_macro = pd.read_csv("macro.csv", parse_dates=['timestamp'])

# %%
#df_train = df_train[df_train['kremlin_km']>=0.1]

# %%
df_train.drop(df_train[df_train["life_sq"] > 7000].index, inplace=True)

mult = 0.969
y_train = df_train['price_doc'].values * mult + 10
id_test = df_test['id']

df_train.drop(['id', 'price_doc'], axis=1, inplace=True)
df_test.drop(['id'], axis=1, inplace=True)

num_train = len(df_train)
df_all = pd.concat([df_train, df_test])
# Next line just adds a lot of NA columns (becuase "join" only works on indexes)
# but somewhow it seems to affect the result
df_all = df_all.join(df_macro, on='timestamp', rsuffix='_macro')
print(df_all.shape)

# Add month-year
month_year = (df_all.timestamp.dt.month + df_all.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
df_all['month_year_cnt'] = month_year.map(month_year_cnt_map)

# Add week-year count
week_year = (df_all.timestamp.dt.weekofyear + df_all.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
df_all['week_year_cnt'] = week_year.map(week_year_cnt_map)

# Add month and day-of-week
df_all['month'] = df_all.timestamp.dt.month
df_all['dow'] = df_all.timestamp.dt.dayofweek

# Other feature engineering
df_all['rel_floor'] = df_all['floor'] / df_all['max_floor'].astype(float)
df_all['rel_kitch_sq'] = df_all['kitch_sq'] / df_all['full_sq'].astype(float)

train['building_name'] = pd.factorize(train.sub_area + train['metro_km_avto'].astype(str))[0]
test['building_name'] = pd.factorize(test.sub_area + test['metro_km_avto'].astype(str))[0]

def add_time_features(col):
   col_month_year = pd.Series(pd.factorize(train[col].astype(str) + month_year.astype(str))[0])
   train[col + '_month_year_cnt'] = col_month_year.map(col_month_year.value_counts())

   col_week_year = pd.Series(pd.factorize(train[col].astype(str) + week_year.astype(str))[0])
   train[col + '_week_year_cnt'] = col_week_year.map(col_week_year.value_counts())

add_time_features('building_name')
add_time_features('sub_area')

def add_time_features(col):
   col_month_year = pd.Series(pd.factorize(test[col].astype(str) + month_year.astype(str))[0])
   test[col + '_month_year_cnt'] = col_month_year.map(col_month_year.value_counts())

   col_week_year = pd.Series(pd.factorize(test[col].astype(str) + week_year.astype(str))[0])
   test[col + '_week_year_cnt'] = col_week_year.map(col_week_year.value_counts())

add_time_features('building_name')
add_time_features('sub_area')


# Remove timestamp column (may overfit the model in train)
df_all.drop(['timestamp', 'timestamp_macro'], axis=1, inplace=True)


factorize = lambda t: pd.factorize(t[1])[0]

df_obj = df_all.select_dtypes(include=['object'])

X_all = np.c_[
    df_all.select_dtypes(exclude=['object']).values,
    np.array(list(map(factorize, df_obj.iteritems()))).T
]
print(X_all.shape)

X_train = X_all[:num_train]
X_test = X_all[num_train:]


# Deal with categorical values
df_numeric = df_all.select_dtypes(exclude=['object'])
df_obj = df_all.select_dtypes(include=['object']).copy()

for c in df_obj:
    df_obj[c] = pd.factorize(df_obj[c])[0]

df_values = pd.concat([df_numeric, df_obj], axis=1)
# Out:
# (38132, 390)
# (38132L, 394L)

# %%
# Convert to numpy values
X_all = df_values.values
print(X_all.shape)

X_train = X_all[:num_train]
X_test = X_all[num_train:]

df_columns = df_values.columns
# Out:
# (38132L, 394L)

# %%
xgb_params = {
    'eta': 0.05,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

# %%
dtrain = xgb.DMatrix(X_train, y_train, feature_names=df_columns)
dtest = xgb.DMatrix(X_test, feature_names=df_columns)

# %%
cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=500, early_stopping_rounds=10,
    verbose_eval=1, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
# Out:
# [0]	train-rmse:7.95074e+06	test-rmse:7.95451e+06
# [1]	train-rmse:7.61722e+06	test-rmse:7.62716e+06
# [2]	train-rmse:7.29768e+06	test-rmse:7.31241e+06
# [3]	train-rmse:6.99728e+06	test-rmse:7.01835e+06
# [4]	train-rmse:6.72402e+06	test-rmse:6.75183e+06
# [5]	train-rmse:6.45535e+06	test-rmse:6.48874e+06
# [6]	train-rmse:6.20117e+06	test-rmse:6.24058e+06
# [7]	train-rmse:5.95433e+06	test-rmse:5.99979e+06
# [8]	train-rmse:5.7313e+06	test-rmse:5.78236e+06
# [9]	train-rmse:5.5252e+06	test-rmse:5.58198e+06
# [10]	train-rmse:5.31881e+06	test-rmse:5.38233e+06
# [11]	train-rmse:5.12794e+06	test-rmse:5.19807e+06
# [12]	train-rmse:4.94649e+06	test-rmse:5.02599e+06
# [13]	train-rmse:4.77751e+06	test-rmse:4.86382e+06
# [14]	train-rmse:4.61944e+06	test-rmse:4.71417e+06
# [15]	train-rmse:4.47011e+06	test-rmse:4.57346e+06
# [16]	train-rmse:4.32918e+06	test-rmse:4.43913e+06
# [17]	train-rmse:4.19718e+06	test-rmse:4.31683e+06
# [18]	train-rmse:4.06871e+06	test-rmse:4.19739e+06
# [19]	train-rmse:3.95198e+06	test-rmse:4.08997e+06
# [20]	train-rmse:3.84164e+06	test-rmse:3.98783e+06
# [21]	train-rmse:3.74226e+06	test-rmse:3.89888e+06
# [22]	train-rmse:3.6444e+06	test-rmse:3.80971e+06
# [23]	train-rmse:3.55377e+06	test-rmse:3.72848e+06
# [24]	train-rmse:3.46997e+06	test-rmse:3.65531e+06
# [25]	train-rmse:3.38991e+06	test-rmse:3.58446e+06
# [26]	train-rmse:3.31695e+06	test-rmse:3.51928e+06
# [27]	train-rmse:3.24584e+06	test-rmse:3.45939e+06
# [28]	train-rmse:3.17908e+06	test-rmse:3.40034e+06
# [29]	train-rmse:3.1176e+06	test-rmse:3.34716e+06
# [30]	train-rmse:3.05966e+06	test-rmse:3.29809e+06
# [31]	train-rmse:3.00636e+06	test-rmse:3.25312e+06
# [32]	train-rmse:2.95965e+06	test-rmse:3.21205e+06
# [33]	train-rmse:2.91171e+06	test-rmse:3.17115e+06
# [34]	train-rmse:2.86416e+06	test-rmse:3.1319e+06
# [35]	train-rmse:2.82206e+06	test-rmse:3.09938e+06
# [36]	train-rmse:2.78369e+06	test-rmse:3.07109e+06
# [37]	train-rmse:2.74973e+06	test-rmse:3.04222e+06
# [38]	train-rmse:2.71626e+06	test-rmse:3.01717e+06
# [39]	train-rmse:2.68483e+06	test-rmse:2.99199e+06
# [40]	train-rmse:2.65593e+06	test-rmse:2.96944e+06
# [41]	train-rmse:2.62743e+06	test-rmse:2.94648e+06
# [42]	train-rmse:2.60343e+06	test-rmse:2.92750e+06
# [43]	train-rmse:2.57685e+06	test-rmse:2.90604e+06
# [44]	train-rmse:2.55841e+06	test-rmse:2.89258e+06
# [45]	train-rmse:2.53721e+06	test-rmse:2.87872e+06
# [46]	train-rmse:2.5181e+06	test-rmse:2.86489e+06
# [47]	train-rmse:2.49643e+06	test-rmse:2.8508e+06
# [48]	train-rmse:2.47742e+06	test-rmse:2.83799e+06
# [49]	train-rmse:2.45853e+06	test-rmse:2.82626e+06
# [50]	train-rmse:2.44147e+06	test-rmse:2.81512e+06
# [51]	train-rmse:2.42751e+06	test-rmse:2.8044e+06
# [52]	train-rmse:2.41203e+06	test-rmse:2.79374e+06
# [53]	train-rmse:2.39924e+06	test-rmse:2.78546e+06
# [54]	train-rmse:2.38564e+06	test-rmse:2.77664e+06
# [55]	train-rmse:2.37447e+06	test-rmse:2.76974e+06
# [56]	train-rmse:2.36304e+06	test-rmse:2.76419e+06
# [57]	train-rmse:2.35234e+06	test-rmse:2.75647e+06
# [58]	train-rmse:2.34312e+06	test-rmse:2.75189e+06
# [59]	train-rmse:2.33359e+06	test-rmse:2.74419e+06
# [60]	train-rmse:2.32403e+06	test-rmse:2.73858e+06
# [61]	train-rmse:2.31616e+06	test-rmse:2.73458e+06
# [62]	train-rmse:2.3078e+06	test-rmse:2.7297e+06
# [63]	train-rmse:2.29837e+06	test-rmse:2.72441e+06
# [64]	train-rmse:2.28993e+06	test-rmse:2.72045e+06
# [65]	train-rmse:2.28358e+06	test-rmse:2.71723e+06
# [66]	train-rmse:2.27738e+06	test-rmse:2.71357e+06
# [67]	train-rmse:2.26866e+06	test-rmse:2.70941e+06
# [68]	train-rmse:2.26184e+06	test-rmse:2.70557e+06
# [69]	train-rmse:2.25302e+06	test-rmse:2.70019e+06
# [70]	train-rmse:2.24669e+06	test-rmse:2.69588e+06
# [71]	train-rmse:2.24197e+06	test-rmse:2.69384e+06
# [72]	train-rmse:2.23628e+06	test-rmse:2.69013e+06
# [73]	train-rmse:2.22895e+06	test-rmse:2.68801e+06
# [74]	train-rmse:2.22264e+06	test-rmse:2.68373e+06
# [75]	train-rmse:2.2178e+06	test-rmse:2.68167e+06
# [76]	train-rmse:2.21169e+06	test-rmse:2.68063e+06
# [77]	train-rmse:2.20582e+06	test-rmse:2.67736e+06
# [78]	train-rmse:2.20007e+06	test-rmse:2.67575e+06
# [79]	train-rmse:2.19393e+06	test-rmse:2.6736e+06
# [80]	train-rmse:2.18962e+06	test-rmse:2.67068e+06
# [81]	train-rmse:2.1852e+06	test-rmse:2.66868e+06
# [82]	train-rmse:2.18075e+06	test-rmse:2.66656e+06
# [83]	train-rmse:2.17725e+06	test-rmse:2.6651e+06
# [84]	train-rmse:2.1726e+06	test-rmse:2.66263e+06
# [85]	train-rmse:2.16931e+06	test-rmse:2.66139e+06
# [86]	train-rmse:2.1648e+06	test-rmse:2.65858e+06
# [87]	train-rmse:2.16038e+06	test-rmse:2.65693e+06
# [88]	train-rmse:2.1561e+06	test-rmse:2.65475e+06
# [89]	train-rmse:2.15156e+06	test-rmse:2.65313e+06
# [90]	train-rmse:2.14732e+06	test-rmse:2.65221e+06
# [91]	train-rmse:2.14314e+06	test-rmse:2.64926e+06
# [92]	train-rmse:2.1397e+06	test-rmse:2.64777e+06
# [93]	train-rmse:2.13737e+06	test-rmse:2.64639e+06
# [94]	train-rmse:2.13425e+06	test-rmse:2.64568e+06
# [95]	train-rmse:2.1313e+06	test-rmse:2.64421e+06
# [96]	train-rmse:2.12811e+06	test-rmse:2.64379e+06
# [97]	train-rmse:2.12503e+06	test-rmse:2.64192e+06
# [98]	train-rmse:2.12186e+06	test-rmse:2.64076e+06
# [99]	train-rmse:2.11903e+06	test-rmse:2.6392e+06
# [100]	train-rmse:2.11491e+06	test-rmse:2.63627e+06
# [101]	train-rmse:2.11196e+06	test-rmse:2.63563e+06
# [102]	train-rmse:2.10895e+06	test-rmse:2.63434e+06
# [103]	train-rmse:2.10524e+06	test-rmse:2.63301e+06
# [104]	train-rmse:2.10311e+06	test-rmse:2.63158e+06
# [105]	train-rmse:2.09945e+06	test-rmse:2.63049e+06
# [106]	train-rmse:2.09562e+06	test-rmse:2.62959e+06
# [107]	train-rmse:2.09281e+06	test-rmse:2.62858e+06
# [108]	train-rmse:2.09049e+06	test-rmse:2.62807e+06
# [109]	train-rmse:2.08724e+06	test-rmse:2.62702e+06
# [110]	train-rmse:2.08419e+06	test-rmse:2.62583e+06
# [111]	train-rmse:2.08128e+06	test-rmse:2.62479e+06
# [112]	train-rmse:2.07842e+06	test-rmse:2.62361e+06
# [113]	train-rmse:2.07559e+06	test-rmse:2.62343e+06
# [114]	train-rmse:2.07323e+06	test-rmse:2.62345e+06
# [115]	train-rmse:2.07056e+06	test-rmse:2.62251e+06
# [116]	train-rmse:2.06832e+06	test-rmse:2.62177e+06
# [117]	train-rmse:2.06601e+06	test-rmse:2.62131e+06
# [118]	train-rmse:2.06338e+06	test-rmse:2.62095e+06
# [119]	train-rmse:2.06024e+06	test-rmse:2.61972e+06
# [120]	train-rmse:2.05792e+06	test-rmse:2.61844e+06
# [121]	train-rmse:2.05567e+06	test-rmse:2.6179e+06
# [122]	train-rmse:2.0537e+06	test-rmse:2.61707e+06
# [123]	train-rmse:2.05119e+06	test-rmse:2.61619e+06
# [124]	train-rmse:2.04935e+06	test-rmse:2.61561e+06
# [125]	train-rmse:2.04702e+06	test-rmse:2.61451e+06
# [126]	train-rmse:2.04556e+06	test-rmse:2.61385e+06
# [127]	train-rmse:2.04237e+06	test-rmse:2.6124e+06
# [128]	train-rmse:2.04012e+06	test-rmse:2.61142e+06
# [129]	train-rmse:2.03842e+06	test-rmse:2.61091e+06
# [130]	train-rmse:2.03577e+06	test-rmse:2.61002e+06
# [131]	train-rmse:2.03377e+06	test-rmse:2.60886e+06
# [132]	train-rmse:2.03095e+06	test-rmse:2.60808e+06
# [133]	train-rmse:2.02937e+06	test-rmse:2.60707e+06
# [134]	train-rmse:2.02726e+06	test-rmse:2.60639e+06
# [135]	train-rmse:2.02506e+06	test-rmse:2.60554e+06
# [136]	train-rmse:2.02276e+06	test-rmse:2.6047e+06
# [137]	train-rmse:2.02066e+06	test-rmse:2.60378e+06
# [138]	train-rmse:2.01734e+06	test-rmse:2.60278e+06
# [139]	train-rmse:2.01452e+06	test-rmse:2.60205e+06
# [140]	train-rmse:2.01194e+06	test-rmse:2.60161e+06
# [141]	train-rmse:2.00903e+06	test-rmse:2.60121e+06
# [142]	train-rmse:2.00782e+06	test-rmse:2.60109e+06
# [143]	train-rmse:2.00616e+06	test-rmse:2.60113e+06
# [144]	train-rmse:2.00371e+06	test-rmse:2.60063e+06
# [145]	train-rmse:2.00242e+06	test-rmse:2.60036e+06
# [146]	train-rmse:1.99995e+06	test-rmse:2.60005e+06
# [147]	train-rmse:1.99861e+06	test-rmse:2.59975e+06
# [148]	train-rmse:1.99657e+06	test-rmse:2.59906e+06
# [149]	train-rmse:1.99529e+06	test-rmse:2.59871e+06
# [150]	train-rmse:1.99338e+06	test-rmse:2.59812e+06
# [151]	train-rmse:1.99028e+06	test-rmse:2.59695e+06
# [152]	train-rmse:1.9878e+06	test-rmse:2.59607e+06
# [153]	train-rmse:1.9849e+06	test-rmse:2.59498e+06
# [154]	train-rmse:1.98248e+06	test-rmse:2.59442e+06
# [155]	train-rmse:1.98022e+06	test-rmse:2.59374e+06
# [156]	train-rmse:1.97778e+06	test-rmse:2.59284e+06
# [157]	train-rmse:1.9765e+06	test-rmse:2.59253e+06
# [158]	train-rmse:1.97355e+06	test-rmse:2.59148e+06
# [159]	train-rmse:1.9721e+06	test-rmse:2.59149e+06
# [160]	train-rmse:1.96921e+06	test-rmse:2.59169e+06
# [161]	train-rmse:1.9671e+06	test-rmse:2.59234e+06
# [162]	train-rmse:1.96566e+06	test-rmse:2.59191e+06
# [163]	train-rmse:1.96395e+06	test-rmse:2.59173e+06
# [164]	train-rmse:1.96142e+06	test-rmse:2.5907e+06
# [165]	train-rmse:1.95972e+06	test-rmse:2.59037e+06
# [166]	train-rmse:1.95832e+06	test-rmse:2.5905e+06
# [167]	train-rmse:1.95655e+06	test-rmse:2.5902e+06
# [168]	train-rmse:1.95528e+06	test-rmse:2.59e+06
# [169]	train-rmse:1.95311e+06	test-rmse:2.59021e+06
# [170]	train-rmse:1.95146e+06	test-rmse:2.59011e+06
# [171]	train-rmse:1.94973e+06	test-rmse:2.58959e+06
# [172]	train-rmse:1.9482e+06	test-rmse:2.58924e+06
# [173]	train-rmse:1.94693e+06	test-rmse:2.58877e+06
# [174]	train-rmse:1.94556e+06	test-rmse:2.58858e+06
# [175]	train-rmse:1.94434e+06	test-rmse:2.588e+06
# [176]	train-rmse:1.94225e+06	test-rmse:2.58722e+06
# [177]	train-rmse:1.94058e+06	test-rmse:2.58686e+06
# [178]	train-rmse:1.93886e+06	test-rmse:2.586e+06
# [179]	train-rmse:1.93685e+06	test-rmse:2.58516e+06
# [180]	train-rmse:1.9349e+06	test-rmse:2.58485e+06
# [181]	train-rmse:1.93335e+06	test-rmse:2.58387e+06
# [182]	train-rmse:1.9317e+06	test-rmse:2.58396e+06
# [183]	train-rmse:1.93044e+06	test-rmse:2.58393e+06
# [184]	train-rmse:1.92877e+06	test-rmse:2.58342e+06
# [185]	train-rmse:1.9267e+06	test-rmse:2.58279e+06
# [186]	train-rmse:1.92512e+06	test-rmse:2.58241e+06
# [187]	train-rmse:1.92375e+06	test-rmse:2.5819e+06
# [188]	train-rmse:1.92147e+06	test-rmse:2.58134e+06
# [189]	train-rmse:1.91988e+06	test-rmse:2.58088e+06
# [190]	train-rmse:1.91885e+06	test-rmse:2.58091e+06
# [191]	train-rmse:1.91644e+06	test-rmse:2.58032e+06
# [192]	train-rmse:1.9142e+06	test-rmse:2.57946e+06
# [193]	train-rmse:1.9128e+06	test-rmse:2.57909e+06
# [194]	train-rmse:1.91005e+06	test-rmse:2.57816e+06
# [195]	train-rmse:1.90862e+06	test-rmse:2.57773e+06
# [196]	train-rmse:1.907e+06	test-rmse:2.57764e+06
# [197]	train-rmse:1.90497e+06	test-rmse:2.57724e+06
# [198]	train-rmse:1.90341e+06	test-rmse:2.57734e+06
# [199]	train-rmse:1.90217e+06	test-rmse:2.57701e+06
# [200]	train-rmse:1.90079e+06	test-rmse:2.57741e+06
# [201]	train-rmse:1.89888e+06	test-rmse:2.57713e+06
# [202]	train-rmse:1.89655e+06	test-rmse:2.57653e+06
# [203]	train-rmse:1.89484e+06	test-rmse:2.57617e+06
# [204]	train-rmse:1.89353e+06	test-rmse:2.57623e+06
# [205]	train-rmse:1.89177e+06	test-rmse:2.57623e+06
# [206]	train-rmse:1.89058e+06	test-rmse:2.57601e+06
# [207]	train-rmse:1.88917e+06	test-rmse:2.57544e+06
# [208]	train-rmse:1.8873e+06	test-rmse:2.57532e+06
# [209]	train-rmse:1.88585e+06	test-rmse:2.57516e+06
# [210]	train-rmse:1.88474e+06	test-rmse:2.57465e+06
# [211]	train-rmse:1.88293e+06	test-rmse:2.57474e+06
# [212]	train-rmse:1.88097e+06	test-rmse:2.57458e+06
# [213]	train-rmse:1.87889e+06	test-rmse:2.57389e+06
# [214]	train-rmse:1.87743e+06	test-rmse:2.57395e+06
# [215]	train-rmse:1.87625e+06	test-rmse:2.57336e+06
# [216]	train-rmse:1.87488e+06	test-rmse:2.57345e+06
# [217]	train-rmse:1.8738e+06	test-rmse:2.57345e+06
# [218]	train-rmse:1.87255e+06	test-rmse:2.57353e+06
# [219]	train-rmse:1.87131e+06	test-rmse:2.57325e+06
# [220]	train-rmse:1.86915e+06	test-rmse:2.57308e+06
# [221]	train-rmse:1.8674e+06	test-rmse:2.57269e+06
# [222]	train-rmse:1.86634e+06	test-rmse:2.57201e+06
# [223]	train-rmse:1.86452e+06	test-rmse:2.57156e+06
# [224]	train-rmse:1.86291e+06	test-rmse:2.57156e+06
# [225]	train-rmse:1.86131e+06	test-rmse:2.57113e+06
# [226]	train-rmse:1.86012e+06	test-rmse:2.5708e+06
# [227]	train-rmse:1.85842e+06	test-rmse:2.57103e+06
# [228]	train-rmse:1.85649e+06	test-rmse:2.5706e+06
# [229]	train-rmse:1.85549e+06	test-rmse:2.57031e+06
# [230]	train-rmse:1.85455e+06	test-rmse:2.57044e+06
# [231]	train-rmse:1.85404e+06	test-rmse:2.57041e+06
# [232]	train-rmse:1.8525e+06	test-rmse:2.57e+06
# [233]	train-rmse:1.85083e+06	test-rmse:2.57001e+06
# [234]	train-rmse:1.84878e+06	test-rmse:2.5694e+06
# [235]	train-rmse:1.84676e+06	test-rmse:2.56875e+06
# [236]	train-rmse:1.84588e+06	test-rmse:2.56868e+06
# [237]	train-rmse:1.84452e+06	test-rmse:2.56872e+06
# [238]	train-rmse:1.84357e+06	test-rmse:2.56859e+06
# [239]	train-rmse:1.84225e+06	test-rmse:2.56823e+06
# [240]	train-rmse:1.84103e+06	test-rmse:2.56805e+06
# [241]	train-rmse:1.83956e+06	test-rmse:2.56778e+06
# [242]	train-rmse:1.8381e+06	test-rmse:2.56744e+06
# [243]	train-rmse:1.83684e+06	test-rmse:2.56718e+06
# [244]	train-rmse:1.83572e+06	test-rmse:2.5673e+06
# [245]	train-rmse:1.83428e+06	test-rmse:2.56718e+06
# [246]	train-rmse:1.83307e+06	test-rmse:2.56702e+06
# [247]	train-rmse:1.83246e+06	test-rmse:2.56699e+06
# [248]	train-rmse:1.83077e+06	test-rmse:2.56667e+06
# [249]	train-rmse:1.8299e+06	test-rmse:2.56676e+06
# [250]	train-rmse:1.82898e+06	test-rmse:2.5667e+06
# [251]	train-rmse:1.82732e+06	test-rmse:2.5668e+06
# [252]	train-rmse:1.82593e+06	test-rmse:2.56669e+06
# [253]	train-rmse:1.82443e+06	test-rmse:2.56628e+06
# [254]	train-rmse:1.823e+06	test-rmse:2.56579e+06
# [255]	train-rmse:1.82149e+06	test-rmse:2.56531e+06
# [256]	train-rmse:1.82068e+06	test-rmse:2.56517e+06
# [257]	train-rmse:1.8194e+06	test-rmse:2.56499e+06
# [258]	train-rmse:1.81742e+06	test-rmse:2.5648e+06
# [259]	train-rmse:1.81592e+06	test-rmse:2.56439e+06
# [260]	train-rmse:1.81479e+06	test-rmse:2.56419e+06
# [261]	train-rmse:1.81354e+06	test-rmse:2.56394e+06
# [262]	train-rmse:1.81247e+06	test-rmse:2.56367e+06
# [263]	train-rmse:1.811e+06	test-rmse:2.56302e+06
# [264]	train-rmse:1.80957e+06	test-rmse:2.56285e+06
# [265]	train-rmse:1.80885e+06	test-rmse:2.56266e+06
# [266]	train-rmse:1.80769e+06	test-rmse:2.56250e+06
# [267]	train-rmse:1.80647e+06	test-rmse:2.56226e+06
# [268]	train-rmse:1.80539e+06	test-rmse:2.56205e+06
# [269]	train-rmse:1.80434e+06	test-rmse:2.56161e+06
# [270]	train-rmse:1.80312e+06	test-rmse:2.56156e+06
# [271]	train-rmse:1.80156e+06	test-rmse:2.5618e+06
# [272]	train-rmse:1.80026e+06	test-rmse:2.56175e+06
# [273]	train-rmse:1.79888e+06	test-rmse:2.56186e+06
# [274]	train-rmse:1.79796e+06	test-rmse:2.56177e+06
# [275]	train-rmse:1.79659e+06	test-rmse:2.56153e+06
# [276]	train-rmse:1.79592e+06	test-rmse:2.56125e+06
# [277]	train-rmse:1.79449e+06	test-rmse:2.56093e+06
# [278]	train-rmse:1.79253e+06	test-rmse:2.56065e+06
# [279]	train-rmse:1.79156e+06	test-rmse:2.5608e+06
# [280]	train-rmse:1.79039e+06	test-rmse:2.56051e+06
# [281]	train-rmse:1.78896e+06	test-rmse:2.56031e+06
# [282]	train-rmse:1.7874e+06	test-rmse:2.56e+06
# [283]	train-rmse:1.78631e+06	test-rmse:2.55951e+06
# [284]	train-rmse:1.78507e+06	test-rmse:2.5591e+06
# [285]	train-rmse:1.78384e+06	test-rmse:2.55893e+06
# [286]	train-rmse:1.78282e+06	test-rmse:2.55886e+06
# [287]	train-rmse:1.78203e+06	test-rmse:2.55882e+06
# [288]	train-rmse:1.78072e+06	test-rmse:2.55865e+06
# [289]	train-rmse:1.77987e+06	test-rmse:2.55851e+06
# [290]	train-rmse:1.77924e+06	test-rmse:2.5585e+06
# [291]	train-rmse:1.77774e+06	test-rmse:2.5584e+06
# [292]	train-rmse:1.77633e+06	test-rmse:2.55833e+06
# [293]	train-rmse:1.77411e+06	test-rmse:2.55836e+06
# [294]	train-rmse:1.77328e+06	test-rmse:2.55828e+06
# [295]	train-rmse:1.77172e+06	test-rmse:2.55813e+06
# [296]	train-rmse:1.77096e+06	test-rmse:2.55793e+06
# [297]	train-rmse:1.76995e+06	test-rmse:2.55785e+06
# [298]	train-rmse:1.76907e+06	test-rmse:2.55771e+06
# [299]	train-rmse:1.76825e+06	test-rmse:2.55763e+06
# [300]	train-rmse:1.76712e+06	test-rmse:2.55761e+06
# [301]	train-rmse:1.7656e+06	test-rmse:2.55745e+06
# [302]	train-rmse:1.76431e+06	test-rmse:2.55769e+06
# [303]	train-rmse:1.76239e+06	test-rmse:2.55711e+06
# [304]	train-rmse:1.76151e+06	test-rmse:2.5568e+06
# [305]	train-rmse:1.76015e+06	test-rmse:2.55666e+06
# [306]	train-rmse:1.75892e+06	test-rmse:2.5564e+06
# [307]	train-rmse:1.75789e+06	test-rmse:2.55611e+06
# [308]	train-rmse:1.75686e+06	test-rmse:2.55616e+06
# [309]	train-rmse:1.75556e+06	test-rmse:2.55604e+06
# [310]	train-rmse:1.75441e+06	test-rmse:2.55594e+06
# [311]	train-rmse:1.7529e+06	test-rmse:2.55552e+06
# [312]	train-rmse:1.75168e+06	test-rmse:2.55536e+06
# [313]	train-rmse:1.75055e+06	test-rmse:2.55526e+06
# [314]	train-rmse:1.7493e+06	test-rmse:2.55479e+06
# [315]	train-rmse:1.74774e+06	test-rmse:2.55485e+06
# [316]	train-rmse:1.74667e+06	test-rmse:2.55461e+06
# [317]	train-rmse:1.74595e+06	test-rmse:2.55457e+06
# [318]	train-rmse:1.74417e+06	test-rmse:2.55455e+06
# [319]	train-rmse:1.74333e+06	test-rmse:2.5542e+06
# [320]	train-rmse:1.74207e+06	test-rmse:2.55391e+06
# [321]	train-rmse:1.74126e+06	test-rmse:2.55385e+06
# [322]	train-rmse:1.74012e+06	test-rmse:2.55372e+06
# [323]	train-rmse:1.7388e+06	test-rmse:2.55345e+06
# [324]	train-rmse:1.73786e+06	test-rmse:2.55352e+06
# [325]	train-rmse:1.73722e+06	test-rmse:2.55333e+06
# [326]	train-rmse:1.73588e+06	test-rmse:2.55307e+06
# [327]	train-rmse:1.7346e+06	test-rmse:2.55297e+06
# [328]	train-rmse:1.73336e+06	test-rmse:2.5529e+06
# [329]	train-rmse:1.73202e+06	test-rmse:2.55283e+06
# [330]	train-rmse:1.73101e+06	test-rmse:2.55268e+06
# [331]	train-rmse:1.72963e+06	test-rmse:2.55284e+06
# [332]	train-rmse:1.72855e+06	test-rmse:2.55286e+06
# [333]	train-rmse:1.72753e+06	test-rmse:2.55293e+06
# [334]	train-rmse:1.72588e+06	test-rmse:2.5529e+06
# [335]	train-rmse:1.72484e+06	test-rmse:2.55294e+06
# [336]	train-rmse:1.72373e+06	test-rmse:2.55285e+06
# [337]	train-rmse:1.72269e+06	test-rmse:2.55294e+06
# [338]	train-rmse:1.72211e+06	test-rmse:2.55316e+06
# [339]	train-rmse:1.72065e+06	test-rmse:2.55287e+06

# %%
len(cv_output)
# Out:
# 331

# %%
num_boost_rounds = len(cv_output) #420  # From Bruno's original CV, I think
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_rounds)

# %%
y_pred = model.predict(dtest)

df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})

# %%
df_sub.to_csv('bruno_June22.csv',index=False)

# %%
df_sub.head()
first_result = output.merge(df_sub, on="id", suffixes=['_louis','_bruno'])
first_result["price_doc"] = np.exp( .714*np.log(first_result.price_doc_louis) +
                                    .286*np.log(first_result.price_doc_bruno) )  # multiplies out to .5 & .2
result = first_result.merge(gunja_output, on="id", suffixes=['_follow','_gunja'])

result["price_doc"] = np.exp( .78*np.log(result.price_doc_follow) +
                              .22*np.log(result.price_doc_gunja) )

# %%
result["price_doc"] =result["price_doc"]*0.9925

# %%
result.drop(["price_doc_louis","price_doc_bruno","price_doc_follow","price_doc_gunja"],axis=1,inplace=True)
result.head()
# Out:
#       id  price_doc
# 0  30474  5309652.0
# 1  30475  8105763.0
# 2  30476  5196011.5
# 3  30477  5745868.5
# 4  30478  4968766.0

# %%
result.to_csv('sub-silly-fixed-price-changed-local_June22.csv', index=False)
